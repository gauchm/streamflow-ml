# %% [markdown]
# ConvLSTM->Conv network, trained on gridded forcing time-series and gridded geophysical data for all stations.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../..')
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
from datetime import datetime, timedelta
from sklearn import preprocessing
import netCDF4 as nc
import torch
from torch import nn, utils
from torch.utils.tensorboard import SummaryWriter
from src import load_data, evaluate, conv_lstm, datasets, utils
import torch.autograd as autograd
import pickle

time_stamp = datetime.now().strftime('%Y%m%d-%H%M%S')
time_stamp
# Out:
# '20190918-101035'

# %%
import logging
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='../../log.out', mode='a')
chandler = logging.StreamHandler(sys.stdout)
formatter = logging.Formatter('%(asctime)s - {} - %(message)s'.format(time_stamp))
fhandler.setFormatter(formatter)
chandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.addHandler(chandler)
logger.setLevel(logging.INFO)

# %%
USE_CUDA = False
if torch.cuda.is_available():
    print('CUDA Available')
    USE_CUDA = True
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
device = torch.device('cuda:0' if USE_CUDA else 'cpu')
num_devices = torch.cuda.device_count() if USE_CUDA else 0
logger.warning('cuda devices: {}'.format(list(torch.cuda.get_device_name(i) for i in range(num_devices))))
torch.manual_seed(0)
np.random.seed(0)
# Out:
# CUDA Available
# 2019-09-18 10:10:35,739 - 20190918-101035 - cuda devices: ['Tesla V100-SXM2-16GB']

# %%
seq_len = 8
seq_steps = 1
stateful_lstm = False
validation_fraction, val_start, val_end = None, None, None

if stateful_lstm:
    val_start = datetime.strptime('2010-01-01', '%Y-%m-%d') + timedelta(days=seq_len * seq_steps)  # first day for which to make a prediction in train set
    val_end = '2010-09-30'
    train_start = '2010-10-01'
    train_end = '2012-12-31'
else:
    validation_fraction = 0.1
    train_start = datetime.strptime('2010-01-01', '%Y-%m-%d') + timedelta(days=seq_len * seq_steps)  # first day for which to make a prediction in train set
    train_end = '2012-12-31'
test_start = '2010-01-09'
test_end = '2014-12-31'

# %%
rdrs_vars = [4, 5]
agg = ['sum', 'minmax']
include_month = True
train_dataset = datasets.RdrsGridDataset(rdrs_vars, seq_len, seq_steps, train_start, train_end, aggregate_daily=agg, include_months=include_month, resample_rdrs=True)
if stateful_lstm:
    val_dataset = datasets.RdrsGridDataset(rdrs_vars, seq_len, seq_steps, val_start, val_end, conv_scalers=train_dataset.conv_scalers, aggregate_daily=agg, include_months=include_month, resample_rdrs=True)
test_dataset = datasets.RdrsGridDataset(rdrs_vars, seq_len, seq_steps, test_start, test_end, conv_scalers=train_dataset.conv_scalers, aggregate_daily=agg, include_months=include_month, resample_rdrs=True)

# %%
landcover_types = None
landcover, landcover_legend = load_data.load_landcover_reduced(values_to_use=landcover_types)
landcover = torch.from_numpy(landcover).float().to(device)

landcover_nc = nc.Dataset('../../data/NA_NALCMS_LC_30m_LAEA_mmu12_urb05_n40-45w75-90_erie.nc', 'r')
landcover_nc.set_auto_mask(False)
erie_lats = landcover_nc['lat'][:][::-1]
erie_lons = landcover_nc['lon'][:]
landcover_nc.close()
erie_lat_min, erie_lat_max, erie_lon_min, erie_lon_max = erie_lats.min(), erie_lats.max(), erie_lons.min(), erie_lons.max()
del erie_lats, erie_lons

logger.warning('Using DEM plus landcover')
dem = load_data.load_dem(erie_lat_min, erie_lat_max, erie_lon_min, erie_lon_max)
dem_reduced = torch.zeros(train_dataset.conv_height, train_dataset.conv_width, device=device)

kernel = dem.shape[0] // dem_reduced.shape[0], dem.shape[1] // dem_reduced.shape[1]
for i in range(dem_reduced.shape[0]):
    for j in range(dem_reduced.shape[1]):
        dem_reduced[i,j] = dem[i*kernel[0]:(i+1)*kernel[0],j*kernel[1]:(j+1)*kernel[1]].mean()
        
landcover = torch.cat([landcover, dem_reduced.reshape((1,*dem_reduced.shape))], dim=0).to(device)
# Out:
# ../../src/load_data.py:419: UserWarning: WARNING: valid_range not used since it
# cannot be safely cast to variable data type
#   landcover_fullres = np.array(landcover_nc['Band1'][:])[::-1,:]
# 2019-09-18 10:13:04,563 - 20190918-101035 - Using DEM plus landcover

# %%
# Train model
num_epochs = 800
learning_rate = 2e-3
patience = 200
min_improvement = 0.01
best_loss_model = (-1, np.inf, None)

# Prepare model
batch_size = 32
num_convlstm_layers = 5
num_conv_layers = 5
convlstm_hidden_dims = [128,64,64,64,32]
conv_hidden_dims = [128,128,64,32]
convlstm_kernel_size = [(3,3)] * num_convlstm_layers
conv_kernel_size = [(3,3)] * num_conv_layers
conv_activation = nn.LeakyReLU
dropout = 0.2
weight_decay = 1e-6

model = conv_lstm.ConvLSTMGridWithGeophysicalInput((train_dataset.conv_height, train_dataset.conv_width), 
                                         train_dataset.n_conv_vars, landcover.shape[0], convlstm_hidden_dims, 
                                         conv_hidden_dims, convlstm_kernel_size, conv_kernel_size, 
                                         num_convlstm_layers, num_conv_layers, conv_activation, dropout=dropout,
                                                  feed_timesteps=seq_len).to(device)
if num_devices > 1:
    model = torch.nn.DataParallel(model, device_ids=list(range(num_devices)))
loss_fn = evaluate.NSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

writer = SummaryWriter(comment='ConvLSTM_withLandcover')
param_description = {'time_stamp': time_stamp, 'H_convlstm': convlstm_hidden_dims, 'H_conv': conv_hidden_dims, 'batch_size': batch_size, 'num_convlstm_layers': num_convlstm_layers, 'num_conv_layers': num_conv_layers, 'convlstm_kernel_size': convlstm_kernel_size, 'conv_kernel_size': conv_kernel_size, 'loss': loss_fn, 
                     'optimizer': optimizer, 'lr': learning_rate, 'patience': patience, 'min_improvement': min_improvement, 'stateful_lstm': stateful_lstm, 'dropout': dropout, 'landcover_shape': landcover.shape, 'conv_activation': conv_activation,
                     'num_epochs': num_epochs, 'seq_len': seq_len, 'seq_steps': seq_steps, 'train_start': train_start, 'train_end': train_end, 'weight_decay': weight_decay, 'validation_fraction': validation_fraction, 'landcover_types': landcover_types,
                     'test_start': test_start, 'test_end': test_end, 'n_conv_vars': train_dataset.n_conv_vars, 'model': str(model).replace('\n','').replace(' ', ''), 'val_start': val_start, 'val_end': val_end, 'aggregate_daily': agg,
                     'train len':len(train_dataset), 'conv_height': train_dataset.conv_height, 'conv_width': train_dataset.conv_width, 'test len': len(test_dataset), 'include_month': include_month}
writer.add_text('Parameter Description', str(param_description))
str(param_description)
# Out:
# "{'time_stamp': '20190918-101035', 'H_convlstm': [128, 64, 64, 64, 32], 'H_conv': [128, 128, 64, 32], 'batch_size': 32, 'num_convlstm_layers': 5, 'num_conv_layers': 5, 'convlstm_kernel_size': [(3, 3), (3, 3), (3, 3), (3, 3), (3, 3)], 'conv_kernel_size': [(3, 3), (3, 3), (3, 3), (3, 3), (3, 3)], 'loss': NSELoss(), 'optimizer': Adam (\nParameter Group 0\n    amsgrad: False\n    betas: (0.9, 0.999)\n    eps: 1e-08\n    lr: 0.002\n    weight_decay: 1e-06\n), 'lr': 0.002, 'patience': 200, 'min_improvement': 0.01, 'stateful_lstm': False, 'dropout': 0.2, 'landcover_shape': torch.Size([20, 34, 39]), 'conv_activation': <class 'torch.nn.modules.activation.LeakyReLU'>, 'num_epochs': 800, 'seq_len': 8, 'seq_steps': 1, 'train_start': datetime.datetime(2010, 1, 9, 0, 0), 'train_end': '2012-12-31', 'weight_decay': 1e-06, 'validation_fraction': 0.1, 'landcover_types': None, 'test_start': '2010-01-09', 'test_end': '2014-12-31', 'n_conv_vars': 15, 'model': 'ConvLSTMGridWithGeophysicalInput((conv_lstm):ConvLSTM((cell_list):ModuleList((0):ConvLSTMCell((conv):Conv2d(143,512,kernel_size=(3,3),stride=(1,1),padding=(1,1)))(1):Identity()(2):ConvLSTMCell((conv):Conv2d(192,256,kernel_size=(3,3),stride=(1,1),padding=(1,1)))(3):Identity()(4):ConvLSTMCell((conv):Conv2d(128,256,kernel_size=(3,3),stride=(1,1),padding=(1,1)))(5):Identity()(6):ConvLSTMCell((conv):Conv2d(128,256,kernel_size=(3,3),stride=(1,1),padding=(1,1)))(7):Identity()(8):ConvLSTMCell((conv):Conv2d(96,128,kernel_size=(3,3),stride=(1,1),padding=(1,1)))(9):Identity()))(dropout):Dropout2d(p=0.2,inplace=False)(upsample):Identity()(conv_out):Sequential((0):BatchNorm2d(276,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)(1):Conv2d(276,128,kernel_size=(3,3),stride=(1,1),padding=(1,1))(2):Dropout(p=0.2,inplace=False)(3):LeakyReLU(negative_slope=0.01)(4):BatchNorm2d(128,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)(5):Conv2d(128,128,kernel_size=(3,3),stride=(1,1),padding=(1,1))(6):LeakyReLU(negative_slope=0.01)(7):Dropout2d(p=0.2,inplace=False)(8):BatchNorm2d(128,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)(9):Conv2d(128,64,kernel_size=(3,3),stride=(1,1),padding=(1,1))(10):LeakyReLU(negative_slope=0.01)(11):Dropout2d(p=0.2,inplace=False)(12):BatchNorm2d(64,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)(13):Conv2d(64,32,kernel_size=(3,3),stride=(1,1),padding=(1,1))(14):LeakyReLU(negative_slope=0.01)(15):Dropout2d(p=0.2,inplace=False)(16):BatchNorm2d(32,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)(17):Conv2d(32,1,kernel_size=(3,3),stride=(1,1),padding=(1,1))))', 'val_start': None, 'val_end': None, 'aggregate_daily': ['sum', 'minmax'], 'train len': 1088, 'conv_height': 34, 'conv_width': 39, 'test len': 1818, 'include_month': True}"

# %%
if stateful_lstm:
    train_sampler = datasets.StatefulBatchSampler(train_dataset, batch_size)
    val_sampler = datasets.StatefulBatchSampler(val_dataset, batch_size)
    test_sampler = datasets.StatefulBatchSampler(test_dataset, batch_size)
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_sampler=train_sampler, pin_memory=True)
    val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_sampler=val_sampler, pin_memory=True)
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_sampler=test_sampler, pin_memory=True)
else:
    val_indices = np.random.choice(len(train_dataset), size=int(validation_fraction * len(train_dataset)), replace=False)
    train_indices = list(i for i in range(len(train_dataset)) if i not in val_indices)
    train_sampler = torch.utils.data.SubsetRandomSampler(train_indices)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_indices)
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, sampler=train_sampler, pin_memory=True, drop_last=False)
    val_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, sampler=val_sampler, pin_memory=True, drop_last=False)
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size, shuffle=False, pin_memory=True, drop_last=False)

# %%
torch.manual_seed(0)
np.random.seed(0)
for epoch in range(num_epochs):
    model.train()

    epoch_losses = torch.tensor(0.0)
    conv_hidden_states = None
    train_means = train_dataset.y_means.reshape(-1).to(device)
    for i, train_batch in enumerate(train_dataloader):
        y_train = train_batch['y'].reshape((train_batch['y'].shape[0],-1)).to(device, non_blocking=True)
        mask = train_batch['mask'].any(dim=0).reshape(-1).to(device, non_blocking=True)
        landcover_batch = landcover.repeat(y_train.shape[0],1,1,1).to(device)
        
        if not mask.any():
            print('Batch {} has no target values. skipping.'.format(i))
            continue
        if not stateful_lstm:
            conv_hidden_states = None
        
        y_pred, conv_hidden_states = model(train_batch['x_conv'].to(device), landcover_batch, hidden_state=conv_hidden_states)
        y_pred = y_pred.reshape((train_batch['y'].shape[0], -1))
        loss = loss_fn(y_pred[:,mask], y_train[:,mask], means=train_means[mask])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        epoch_losses += loss.detach()
        
    epoch_loss = (epoch_losses / len(train_dataloader)).item()
    print('Epoch', epoch, 'mean train loss:\t{}'.format(epoch_loss))
    writer.add_scalar('loss_nse', epoch_loss, epoch)
    
    # eval on validation split
    model.eval()
    val_losses = torch.tensor(0.0)
    conv_hidden_states = None
    for i, val_batch in enumerate(val_dataloader):
        y_val = val_batch['y'].reshape((val_batch['y'].shape[0],-1)).to(device, non_blocking=True)
        mask = val_batch['mask'].any(dim=0).reshape(-1).to(device, non_blocking=True)
        landcover_batch = landcover.repeat(y_val.shape[0],1,1,1).to(device)
        
        if not stateful_lstm:
            conv_hidden_states = None
        
        batch_pred, conv_hidden_states = model(val_batch['x_conv'].to(device), landcover_batch, hidden_state=conv_hidden_states)
        batch_pred = batch_pred.detach().reshape((val_batch['y'].shape[0], -1))
        val_losses += loss_fn(batch_pred[:,mask], y_val[:,mask], means=train_means[mask]).detach()
        
    val_nse = (val_losses / len(val_dataloader)).item()
    print('Epoch {} mean val loss:  \t{}'.format(epoch, val_nse))
    writer.add_scalar('loss_nse_val', val_nse, epoch)
    if val_nse < best_loss_model[1] - min_improvement:
        best_loss_model = (epoch, val_nse, model.state_dict())  # new best model
        load_data.pickle_model('ConvLSTM_withLandcover', model, 'allStations', time_stamp)
    elif epoch > best_loss_model[0] + patience:
        print('Patience exhausted in epoch {}. Best val-loss was {}'.format(epoch, best_loss_model[1]))
        break
    
print('Using best model from epoch', str(best_loss_model[0]), 'which had loss', str(best_loss_model[1]))
model.load_state_dict(best_loss_model[2])
load_data.pickle_model('ConvLSTM_withLandcover', model, 'allStations', time_stamp)
# Out:
# Epoch 0 mean train loss:	1.2577334642410278
# Epoch 0 mean val loss:  	1.3117254972457886
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 1 mean train loss:	1.1654514074325562
# Epoch 1 mean val loss:  	1.2769443988800049
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 2 mean train loss:	1.133606195449829
# Epoch 2 mean val loss:  	1.1788194179534912
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 3 mean train loss:	1.0803948640823364
# Epoch 3 mean val loss:  	1.1282590627670288
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 4 mean train loss:	1.0152933597564697
# Epoch 4 mean val loss:  	1.1000874042510986
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 5 mean train loss:	0.9574065208435059
# Epoch 5 mean val loss:  	0.9388397932052612
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 6 mean train loss:	0.8784302473068237
# Epoch 6 mean val loss:  	0.8577422499656677
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 7 mean train loss:	0.8714544773101807
# Epoch 7 mean val loss:  	0.815128743648529
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 8 mean train loss:	0.8460451364517212
# Epoch 8 mean val loss:  	0.7791005373001099
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 9 mean train loss:	0.8160865306854248
# Epoch 9 mean val loss:  	0.7324618101119995
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 10 mean train loss:	0.7821884155273438
# Epoch 10 mean val loss:  	0.852199912071228
# Epoch 11 mean train loss:	0.7298033833503723
# Epoch 11 mean val loss:  	0.6541731357574463
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 12 mean train loss:	0.6916582584381104
# Epoch 12 mean val loss:  	1.0095877647399902
# Epoch 13 mean train loss:	0.7348673939704895
# Epoch 13 mean val loss:  	0.7136728763580322
# Epoch 14 mean train loss:	0.6950560808181763
# Epoch 14 mean val loss:  	0.6322450041770935
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 15 mean train loss:	0.6678912043571472
# Epoch 15 mean val loss:  	0.593743085861206
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 16 mean train loss:	0.6225632429122925
# Epoch 16 mean val loss:  	0.6349694728851318
# Epoch 17 mean train loss:	0.6574134230613708
# Epoch 17 mean val loss:  	0.6664760112762451
# Epoch 18 mean train loss:	0.6384119987487793
# Epoch 18 mean val loss:  	0.6265263557434082
# Epoch 19 mean train loss:	0.6296950578689575
# Epoch 19 mean val loss:  	0.6403579115867615
# Epoch 20 mean train loss:	0.624138593673706
# Epoch 20 mean val loss:  	0.6513715386390686
# Epoch 21 mean train loss:	0.6038302779197693
# Epoch 21 mean val loss:  	1.2014274597167969
# Epoch 22 mean train loss:	0.5569717884063721
# Epoch 22 mean val loss:  	0.5847536325454712
# Epoch 23 mean train loss:	0.5669035911560059
# Epoch 23 mean val loss:  	0.6148532629013062
# Epoch 24 mean train loss:	0.5535386800765991
# Epoch 24 mean val loss:  	0.559567928314209
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 25 mean train loss:	0.5259864926338196
# Epoch 25 mean val loss:  	0.481873482465744
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 26 mean train loss:	0.5323544144630432
# Epoch 26 mean val loss:  	0.5263766050338745
# Epoch 27 mean train loss:	0.5040566921234131
# Epoch 27 mean val loss:  	1.018440842628479
# Epoch 28 mean train loss:	0.5216237902641296
# Epoch 28 mean val loss:  	0.8720641136169434
# Epoch 29 mean train loss:	0.49604737758636475
# Epoch 29 mean val loss:  	0.9147132635116577
# Epoch 30 mean train loss:	0.49281537532806396
# Epoch 30 mean val loss:  	0.5304053425788879
# Epoch 31 mean train loss:	0.4439114034175873
# Epoch 31 mean val loss:  	0.6064417958259583
# Epoch 32 mean train loss:	0.46399447321891785
# Epoch 32 mean val loss:  	0.6594687700271606
# Epoch 33 mean train loss:	0.4686102569103241
# Epoch 33 mean val loss:  	0.5743305683135986
# Epoch 34 mean train loss:	0.461051881313324
# Epoch 34 mean val loss:  	0.47217458486557007
# Epoch 35 mean train loss:	0.4592023193836212
# Epoch 35 mean val loss:  	0.562046468257904
# Epoch 36 mean train loss:	0.46952179074287415
# Epoch 36 mean val loss:  	0.43853759765625
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 37 mean train loss:	0.4626067280769348
# Epoch 37 mean val loss:  	0.5616730451583862
# Epoch 38 mean train loss:	0.4452905058860779
# Epoch 38 mean val loss:  	0.424193412065506
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 39 mean train loss:	0.4274657368659973
# Epoch 39 mean val loss:  	0.41838788986206055
# Epoch 40 mean train loss:	0.4236997365951538
# Epoch 40 mean val loss:  	0.5046095848083496
# Epoch 41 mean train loss:	0.40499159693717957
# Epoch 41 mean val loss:  	0.45823490619659424
# Epoch 42 mean train loss:	0.38343995809555054
# Epoch 42 mean val loss:  	0.5264965295791626
# Epoch 43 mean train loss:	0.41011837124824524
# Epoch 43 mean val loss:  	0.5267811417579651
# Epoch 44 mean train loss:	0.3893398642539978
# Epoch 44 mean val loss:  	0.6293759346008301
# Epoch 45 mean train loss:	0.39510929584503174
# Epoch 45 mean val loss:  	0.4639061987400055
# Epoch 46 mean train loss:	0.3824926018714905
# Epoch 46 mean val loss:  	0.4704209566116333
# Epoch 47 mean train loss:	0.3676798939704895
# Epoch 47 mean val loss:  	0.5172926187515259
# Epoch 48 mean train loss:	0.3574741780757904
# Epoch 48 mean val loss:  	0.4369543194770813
# Epoch 49 mean train loss:	0.3555868864059448
# Epoch 49 mean val loss:  	0.4693133533000946
# Epoch 50 mean train loss:	0.3408108949661255
# Epoch 50 mean val loss:  	0.4472416639328003
# Epoch 51 mean train loss:	0.3602808117866516
# Epoch 51 mean val loss:  	0.44869881868362427
# Epoch 52 mean train loss:	0.3712799549102783
# Epoch 52 mean val loss:  	0.5042809844017029
# Epoch 53 mean train loss:	0.3374005854129791
# Epoch 53 mean val loss:  	0.4322062134742737
# Epoch 54 mean train loss:	0.3348621726036072
# Epoch 54 mean val loss:  	0.44346439838409424
# Epoch 55 mean train loss:	0.3373459577560425
# Epoch 55 mean val loss:  	0.4425632059574127
# Epoch 56 mean train loss:	0.4322200417518616
# Epoch 56 mean val loss:  	0.4746471643447876
# Epoch 57 mean train loss:	0.39521142840385437
# Epoch 57 mean val loss:  	0.487174928188324
# Epoch 58 mean train loss:	0.36180710792541504
# Epoch 58 mean val loss:  	0.49039822816848755
# Epoch 59 mean train loss:	0.32897207140922546
# Epoch 59 mean val loss:  	0.4187301695346832
# Epoch 60 mean train loss:	0.3432124853134155
# Epoch 60 mean val loss:  	0.5924668312072754
# Epoch 61 mean train loss:	0.34772631525993347
# Epoch 61 mean val loss:  	0.4440786838531494
# Epoch 62 mean train loss:	0.3305630087852478
# Epoch 62 mean val loss:  	0.40265506505966187
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 63 mean train loss:	0.3317110240459442
# Epoch 63 mean val loss:  	0.4268801808357239
# Epoch 64 mean train loss:	0.3169194161891937
# Epoch 64 mean val loss:  	0.4998489022254944
# Epoch 65 mean train loss:	0.32607582211494446
# Epoch 65 mean val loss:  	0.37499624490737915
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 66 mean train loss:	0.35313454270362854
# Epoch 66 mean val loss:  	0.5220800638198853
# Epoch 67 mean train loss:	0.32256418466567993
# Epoch 67 mean val loss:  	0.39748716354370117
# Epoch 68 mean train loss:	0.32059910893440247
# Epoch 68 mean val loss:  	0.393663227558136
# Epoch 69 mean train loss:	0.310795396566391
# Epoch 69 mean val loss:  	0.354195237159729
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 70 mean train loss:	0.30598101019859314
# Epoch 70 mean val loss:  	0.48301565647125244
# Epoch 71 mean train loss:	0.29701027274131775
# Epoch 71 mean val loss:  	0.41049715876579285
# Epoch 72 mean train loss:	0.2973152697086334
# Epoch 72 mean val loss:  	0.39519327878952026
# Epoch 73 mean train loss:	0.306186318397522
# Epoch 73 mean val loss:  	0.3643573522567749
# Epoch 74 mean train loss:	0.30084872245788574
# Epoch 74 mean val loss:  	0.34925755858421326
# Epoch 75 mean train loss:	0.2824108898639679
# Epoch 75 mean val loss:  	0.31922581791877747
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 76 mean train loss:	0.2929157614707947
# Epoch 76 mean val loss:  	0.3612584173679352
# Epoch 77 mean train loss:	0.2726544737815857
# Epoch 77 mean val loss:  	0.4171290397644043
# Epoch 78 mean train loss:	0.27437224984169006
# Epoch 78 mean val loss:  	0.47772935032844543
# Epoch 79 mean train loss:	0.284807026386261
# Epoch 79 mean val loss:  	0.365989089012146
# Epoch 80 mean train loss:	0.26732340455055237
# Epoch 80 mean val loss:  	0.4913996160030365
# Epoch 81 mean train loss:	0.2707812488079071
# Epoch 81 mean val loss:  	0.36690518260002136
# Epoch 82 mean train loss:	0.26012346148490906
# Epoch 82 mean val loss:  	0.29902419447898865
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 83 mean train loss:	0.25807464122772217
# Epoch 83 mean val loss:  	0.3360247015953064
# Epoch 84 mean train loss:	0.2573253810405731
# Epoch 84 mean val loss:  	0.34198084473609924
# Epoch 85 mean train loss:	0.2569759786128998
# Epoch 85 mean val loss:  	0.3306245803833008
# Epoch 86 mean train loss:	0.2827058732509613
# Epoch 86 mean val loss:  	0.4583548307418823
# Epoch 87 mean train loss:	0.3278495967388153
# Epoch 87 mean val loss:  	0.3959982097148895
# Epoch 88 mean train loss:	0.2916692793369293
# Epoch 88 mean val loss:  	0.36689257621765137
# Epoch 89 mean train loss:	0.2923491597175598
# Epoch 89 mean val loss:  	0.38628724217414856
# Epoch 90 mean train loss:	0.2742016911506653
# Epoch 90 mean val loss:  	0.3808640241622925
# Epoch 91 mean train loss:	0.24716348946094513
# Epoch 91 mean val loss:  	0.3516884446144104
# Epoch 92 mean train loss:	0.24041934311389923
# Epoch 92 mean val loss:  	0.44138064980506897
# Epoch 93 mean train loss:	0.24716494977474213
# Epoch 93 mean val loss:  	0.35520046949386597
# Epoch 94 mean train loss:	0.27030304074287415
# Epoch 94 mean val loss:  	0.3871140480041504
# Epoch 95 mean train loss:	0.26318618655204773
# Epoch 95 mean val loss:  	0.6108769178390503
# Epoch 96 mean train loss:	0.2534262537956238
# Epoch 96 mean val loss:  	0.34018102288246155
# Epoch 97 mean train loss:	0.2457839399576187
# Epoch 97 mean val loss:  	0.34385499358177185
# Epoch 98 mean train loss:	0.25552114844322205
# Epoch 98 mean val loss:  	0.29092222452163696
# Epoch 99 mean train loss:	0.2483150064945221
# Epoch 99 mean val loss:  	0.3989156484603882
# Epoch 100 mean train loss:	0.25200432538986206
# Epoch 100 mean val loss:  	0.30914464592933655
# Epoch 101 mean train loss:	0.25505390763282776
# Epoch 101 mean val loss:  	0.37981581687927246
# Epoch 102 mean train loss:	0.24962641298770905
# Epoch 102 mean val loss:  	0.5038577318191528
# Epoch 103 mean train loss:	0.22995160520076752
# Epoch 103 mean val loss:  	0.3299880623817444
# Epoch 104 mean train loss:	0.23539766669273376
# Epoch 104 mean val loss:  	0.3422592282295227
# Epoch 105 mean train loss:	0.23475128412246704
# Epoch 105 mean val loss:  	0.34717869758605957
# Epoch 106 mean train loss:	0.23630033433437347
# Epoch 106 mean val loss:  	0.5573285222053528
# Epoch 107 mean train loss:	0.23790086805820465
# Epoch 107 mean val loss:  	0.34603193402290344
# Epoch 108 mean train loss:	0.237447127699852
# Epoch 108 mean val loss:  	0.408866822719574
# Epoch 109 mean train loss:	0.24305403232574463
# Epoch 109 mean val loss:  	0.3401121497154236
# Epoch 110 mean train loss:	0.23074069619178772
# Epoch 110 mean val loss:  	0.3591575622558594
# Epoch 111 mean train loss:	0.21072162687778473
# Epoch 111 mean val loss:  	0.35609015822410583
# Epoch 112 mean train loss:	0.22354550659656525
# Epoch 112 mean val loss:  	0.5290296077728271
# Epoch 113 mean train loss:	0.22566203773021698
# Epoch 113 mean val loss:  	0.3428043723106384
# Epoch 114 mean train loss:	0.22972151637077332
# Epoch 114 mean val loss:  	0.40259304642677307
# Epoch 115 mean train loss:	0.22600342333316803
# Epoch 115 mean val loss:  	0.37947404384613037
# Epoch 116 mean train loss:	0.2324754148721695
# Epoch 116 mean val loss:  	0.3303394317626953
# Epoch 117 mean train loss:	0.2055065780878067
# Epoch 117 mean val loss:  	0.3338441848754883
# Epoch 118 mean train loss:	0.20688937604427338
# Epoch 118 mean val loss:  	0.3955364227294922
# Epoch 119 mean train loss:	0.2157829850912094
# Epoch 119 mean val loss:  	0.3143477737903595
# Epoch 120 mean train loss:	0.2073730081319809
# Epoch 120 mean val loss:  	0.3558827340602875
# Epoch 121 mean train loss:	0.20529620349407196
# Epoch 121 mean val loss:  	0.3320797085762024
# Epoch 122 mean train loss:	0.19913721084594727
# Epoch 122 mean val loss:  	0.4257073402404785
# Epoch 123 mean train loss:	0.20166194438934326
# Epoch 123 mean val loss:  	0.3448236882686615
# Epoch 124 mean train loss:	0.2137409746646881
# Epoch 124 mean val loss:  	0.322354793548584
# Epoch 125 mean train loss:	0.2039126753807068
# Epoch 125 mean val loss:  	0.3138069212436676
# Epoch 126 mean train loss:	0.20344744622707367
# Epoch 126 mean val loss:  	0.3712753653526306
# Epoch 127 mean train loss:	0.19344894587993622
# Epoch 127 mean val loss:  	0.3004300892353058
# Epoch 128 mean train loss:	0.187856525182724
# Epoch 128 mean val loss:  	0.35824310779571533
# Epoch 129 mean train loss:	0.2022918313741684
# Epoch 129 mean val loss:  	0.3435051441192627
# Epoch 130 mean train loss:	0.19202759861946106
# Epoch 130 mean val loss:  	0.35561445355415344
# Epoch 131 mean train loss:	0.21048365533351898
# Epoch 131 mean val loss:  	0.29643183946609497
# Epoch 132 mean train loss:	0.17417719960212708
# Epoch 132 mean val loss:  	0.40045878291130066
# Epoch 133 mean train loss:	0.18367187678813934
# Epoch 133 mean val loss:  	0.37649795413017273
# Epoch 134 mean train loss:	0.19755537807941437
# Epoch 134 mean val loss:  	0.29326823353767395
# Epoch 135 mean train loss:	0.18955586850643158
# Epoch 135 mean val loss:  	0.2741163671016693
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 136 mean train loss:	0.19855661690235138
# Epoch 136 mean val loss:  	0.3243575990200043
# Epoch 137 mean train loss:	0.1997900754213333
# Epoch 137 mean val loss:  	0.30364707112312317
# Epoch 138 mean train loss:	0.18737685680389404
# Epoch 138 mean val loss:  	0.2833749055862427
# Epoch 139 mean train loss:	0.18635603785514832
# Epoch 139 mean val loss:  	0.35040420293807983
# Epoch 140 mean train loss:	0.19806186854839325
# Epoch 140 mean val loss:  	0.38353005051612854
# Epoch 141 mean train loss:	0.19231174886226654
# Epoch 141 mean val loss:  	0.3210670053958893
# Epoch 142 mean train loss:	0.1697532832622528
# Epoch 142 mean val loss:  	0.32829251885414124
# Epoch 143 mean train loss:	0.1711006611585617
# Epoch 143 mean val loss:  	0.29505428671836853
# Epoch 144 mean train loss:	0.17028239369392395
# Epoch 144 mean val loss:  	0.2935416102409363
# Epoch 145 mean train loss:	0.17822915315628052
# Epoch 145 mean val loss:  	0.31180524826049805
# Epoch 146 mean train loss:	0.18058298528194427
# Epoch 146 mean val loss:  	0.2958928942680359
# Epoch 147 mean train loss:	0.19335933029651642
# Epoch 147 mean val loss:  	0.34327465295791626
# Epoch 148 mean train loss:	0.17566804587841034
# Epoch 148 mean val loss:  	0.33601975440979004
# Epoch 149 mean train loss:	0.17264321446418762
# Epoch 149 mean val loss:  	0.39781254529953003
# Epoch 150 mean train loss:	0.1797223687171936
# Epoch 150 mean val loss:  	0.2697404623031616
# Epoch 151 mean train loss:	0.1717086285352707
# Epoch 151 mean val loss:  	0.3006213903427124
# Epoch 152 mean train loss:	0.18113332986831665
# Epoch 152 mean val loss:  	0.3022500276565552
# Epoch 153 mean train loss:	0.172356978058815
# Epoch 153 mean val loss:  	0.3667144775390625
# Epoch 154 mean train loss:	0.18472518026828766
# Epoch 154 mean val loss:  	0.3235644996166229
# Epoch 155 mean train loss:	0.16014531254768372
# Epoch 155 mean val loss:  	0.39184504747390747
# Epoch 156 mean train loss:	0.1539580076932907
# Epoch 156 mean val loss:  	0.28759562969207764
# Epoch 157 mean train loss:	0.16161467134952545
# Epoch 157 mean val loss:  	0.41716015338897705
# Epoch 158 mean train loss:	0.16206498444080353
# Epoch 158 mean val loss:  	0.2708350718021393
# Epoch 159 mean train loss:	0.16402028501033783
# Epoch 159 mean val loss:  	0.2963949143886566
# Epoch 160 mean train loss:	0.15767808258533478
# Epoch 160 mean val loss:  	0.3508871793746948
# Epoch 161 mean train loss:	0.15720456838607788
# Epoch 161 mean val loss:  	0.3521800935268402
# Epoch 162 mean train loss:	0.16169415414333344
# Epoch 162 mean val loss:  	0.35361143946647644
# Epoch 163 mean train loss:	0.16679413616657257
# Epoch 163 mean val loss:  	0.34017473459243774
# Epoch 164 mean train loss:	0.16431602835655212
# Epoch 164 mean val loss:  	0.2988458275794983
# Epoch 165 mean train loss:	0.15826644003391266
# Epoch 165 mean val loss:  	0.3130875825881958
# Epoch 166 mean train loss:	0.18549537658691406
# Epoch 166 mean val loss:  	0.3162326514720917
# Epoch 167 mean train loss:	0.1824307143688202
# Epoch 167 mean val loss:  	0.3184928297996521
# Epoch 168 mean train loss:	0.16508188843727112
# Epoch 168 mean val loss:  	0.31201091408729553
# Epoch 169 mean train loss:	0.16298310458660126
# Epoch 169 mean val loss:  	0.2912669777870178
# Epoch 170 mean train loss:	0.15379853546619415
# Epoch 170 mean val loss:  	0.3479858934879303
# Epoch 171 mean train loss:	0.15100409090518951
# Epoch 171 mean val loss:  	0.2632952928543091
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 172 mean train loss:	0.1611809879541397
# Epoch 172 mean val loss:  	0.2665844261646271
# Epoch 173 mean train loss:	0.14518842101097107
# Epoch 173 mean val loss:  	0.2694457769393921
# Epoch 174 mean train loss:	0.14530575275421143
# Epoch 174 mean val loss:  	0.24282410740852356
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 175 mean train loss:	0.15498696267604828
# Epoch 175 mean val loss:  	0.34357231855392456
# Epoch 176 mean train loss:	0.16212981939315796
# Epoch 176 mean val loss:  	0.3209414482116699
# Epoch 177 mean train loss:	0.15024855732917786
# Epoch 177 mean val loss:  	0.336983859539032
# Epoch 178 mean train loss:	0.1529606133699417
# Epoch 178 mean val loss:  	0.2891556918621063
# Epoch 179 mean train loss:	0.1479334533214569
# Epoch 179 mean val loss:  	0.29600074887275696
# Epoch 180 mean train loss:	0.14747950434684753
# Epoch 180 mean val loss:  	0.30641791224479675
# Epoch 181 mean train loss:	0.1514531672000885
# Epoch 181 mean val loss:  	0.289958655834198
# Epoch 182 mean train loss:	0.14900049567222595
# Epoch 182 mean val loss:  	0.3255717158317566
# Epoch 183 mean train loss:	0.15734775364398956
# Epoch 183 mean val loss:  	0.284094899892807
# Epoch 184 mean train loss:	0.15468044579029083
# Epoch 184 mean val loss:  	0.3182776868343353
# Epoch 185 mean train loss:	0.1568925827741623
# Epoch 185 mean val loss:  	0.32797545194625854
# Epoch 186 mean train loss:	0.16281262040138245
# Epoch 186 mean val loss:  	0.28643542528152466
# Epoch 187 mean train loss:	0.1554233431816101
# Epoch 187 mean val loss:  	0.2929074168205261
# Epoch 188 mean train loss:	0.14763875305652618
# Epoch 188 mean val loss:  	0.2725594639778137
# Epoch 189 mean train loss:	0.16098813712596893
# Epoch 189 mean val loss:  	0.3231354057788849
# Epoch 190 mean train loss:	0.15145233273506165
# Epoch 190 mean val loss:  	0.28955185413360596
# Epoch 191 mean train loss:	0.14349742233753204
# Epoch 191 mean val loss:  	0.33279621601104736
# Epoch 192 mean train loss:	0.15053947269916534
# Epoch 192 mean val loss:  	0.2950301170349121
# Epoch 193 mean train loss:	0.14657121896743774
# Epoch 193 mean val loss:  	0.3019056022167206
# Epoch 194 mean train loss:	0.13845160603523254
# Epoch 194 mean val loss:  	0.26694390177726746
# Epoch 195 mean train loss:	0.14541961252689362
# Epoch 195 mean val loss:  	0.260297954082489
# Epoch 196 mean train loss:	0.15049797296524048
# Epoch 196 mean val loss:  	0.3078814148902893
# Epoch 197 mean train loss:	0.1504696160554886
# Epoch 197 mean val loss:  	0.2580280303955078
# Epoch 198 mean train loss:	0.1622421145439148
# Epoch 198 mean val loss:  	0.3138442039489746
# Epoch 199 mean train loss:	0.16169843077659607
# Epoch 199 mean val loss:  	0.2898116111755371
# Epoch 200 mean train loss:	0.15436409413814545
# Epoch 200 mean val loss:  	0.31086134910583496
# Epoch 201 mean train loss:	0.14288848638534546
# Epoch 201 mean val loss:  	0.3107229769229889
# Epoch 202 mean train loss:	0.12889933586120605
# Epoch 202 mean val loss:  	0.2832868695259094
# Epoch 203 mean train loss:	0.1438998132944107
# Epoch 203 mean val loss:  	0.26954442262649536
# Epoch 204 mean train loss:	0.1579335331916809
# Epoch 204 mean val loss:  	0.283218652009964
# Epoch 205 mean train loss:	0.12928253412246704
# Epoch 205 mean val loss:  	0.260432630777359
# Epoch 206 mean train loss:	0.13578276336193085
# Epoch 206 mean val loss:  	0.27725085616111755
# Epoch 207 mean train loss:	0.1367999017238617
# Epoch 207 mean val loss:  	0.2617844343185425
# Epoch 208 mean train loss:	0.1374569833278656
# Epoch 208 mean val loss:  	0.2899788022041321
# Epoch 209 mean train loss:	0.14721789956092834
# Epoch 209 mean val loss:  	0.3946770429611206
# Epoch 210 mean train loss:	0.1461258828639984
# Epoch 210 mean val loss:  	0.3186165690422058
# Epoch 211 mean train loss:	0.14358149468898773
# Epoch 211 mean val loss:  	0.3249748945236206
# Epoch 212 mean train loss:	0.144546777009964
# Epoch 212 mean val loss:  	0.3231468200683594
# Epoch 213 mean train loss:	0.1409224271774292
# Epoch 213 mean val loss:  	0.3025582730770111
# Epoch 214 mean train loss:	0.1358538419008255
# Epoch 214 mean val loss:  	0.35279756784439087
# Epoch 215 mean train loss:	0.13918988406658173
# Epoch 215 mean val loss:  	0.2817794680595398
# Epoch 216 mean train loss:	0.13483721017837524
# Epoch 216 mean val loss:  	0.2841311991214752
# Epoch 217 mean train loss:	0.1297507882118225
# Epoch 217 mean val loss:  	0.28115516901016235
# Epoch 218 mean train loss:	0.14090852439403534
# Epoch 218 mean val loss:  	0.3100033700466156
# Epoch 219 mean train loss:	0.1304284930229187
# Epoch 219 mean val loss:  	0.369293749332428
# Epoch 220 mean train loss:	0.134017214179039
# Epoch 220 mean val loss:  	0.324022114276886
# Epoch 221 mean train loss:	0.13841521739959717
# Epoch 221 mean val loss:  	0.30555814504623413
# Epoch 222 mean train loss:	0.13465075194835663
# Epoch 222 mean val loss:  	0.2674824297428131
# Epoch 223 mean train loss:	0.1257397085428238
# Epoch 223 mean val loss:  	0.23610204458236694
# Epoch 224 mean train loss:	0.129148930311203
# Epoch 224 mean val loss:  	0.23882323503494263
# Epoch 225 mean train loss:	0.12429186701774597
# Epoch 225 mean val loss:  	0.2553386688232422
# Epoch 226 mean train loss:	0.1299881488084793
# Epoch 226 mean val loss:  	0.26575756072998047
# Epoch 227 mean train loss:	0.1257881373167038
# Epoch 227 mean val loss:  	0.35391953587532043
# Epoch 228 mean train loss:	0.12572583556175232
# Epoch 228 mean val loss:  	0.2892213761806488
# Epoch 229 mean train loss:	0.1242944523692131
# Epoch 229 mean val loss:  	0.31697070598602295
# Epoch 230 mean train loss:	0.12904497981071472
# Epoch 230 mean val loss:  	0.3154119849205017
# Epoch 231 mean train loss:	0.13004298508167267
# Epoch 231 mean val loss:  	0.2618770897388458
# Epoch 232 mean train loss:	0.14342276751995087
# Epoch 232 mean val loss:  	0.27357718348503113
# Epoch 233 mean train loss:	0.13467910885810852
# Epoch 233 mean val loss:  	0.3023689389228821
# Epoch 234 mean train loss:	0.13293175399303436
# Epoch 234 mean val loss:  	0.2600550055503845
# Epoch 235 mean train loss:	0.1248176246881485
# Epoch 235 mean val loss:  	0.2895231246948242
# Epoch 236 mean train loss:	0.11837586015462875
# Epoch 236 mean val loss:  	0.2566203474998474
# Epoch 237 mean train loss:	0.11728984862565994
# Epoch 237 mean val loss:  	0.28565382957458496
# Epoch 238 mean train loss:	0.12652665376663208
# Epoch 238 mean val loss:  	0.251694917678833
# Epoch 239 mean train loss:	0.11656778305768967
# Epoch 239 mean val loss:  	0.2649087905883789
# Epoch 240 mean train loss:	0.11916065961122513
# Epoch 240 mean val loss:  	0.28963184356689453
# Epoch 241 mean train loss:	0.11778640002012253
# Epoch 241 mean val loss:  	0.2801353335380554
# Epoch 242 mean train loss:	0.13381919264793396
# Epoch 242 mean val loss:  	0.332736074924469
# Epoch 243 mean train loss:	0.11750508099794388
# Epoch 243 mean val loss:  	0.29041439294815063
# Epoch 244 mean train loss:	0.1295810043811798
# Epoch 244 mean val loss:  	0.268219530582428
# Epoch 245 mean train loss:	0.12401556968688965
# Epoch 245 mean val loss:  	0.24024537205696106
# Epoch 246 mean train loss:	0.12433037906885147
# Epoch 246 mean val loss:  	0.26170116662979126
# Epoch 247 mean train loss:	0.11775682866573334
# Epoch 247 mean val loss:  	0.2903186082839966
# Epoch 248 mean train loss:	0.12314717471599579
# Epoch 248 mean val loss:  	0.38178396224975586
# Epoch 249 mean train loss:	0.12616336345672607
# Epoch 249 mean val loss:  	0.46841663122177124
# Epoch 250 mean train loss:	0.12895473837852478
# Epoch 250 mean val loss:  	0.2745824456214905
# Epoch 251 mean train loss:	0.11924710124731064
# Epoch 251 mean val loss:  	0.282643586397171
# Epoch 252 mean train loss:	0.11225895583629608
# Epoch 252 mean val loss:  	0.24419938027858734
# Epoch 253 mean train loss:	0.11579650640487671
# Epoch 253 mean val loss:  	0.291547030210495
# Epoch 254 mean train loss:	0.126077339053154
# Epoch 254 mean val loss:  	0.29789960384368896
# Epoch 255 mean train loss:	0.1250818967819214
# Epoch 255 mean val loss:  	0.3397591710090637
# Epoch 256 mean train loss:	0.12248941510915756
# Epoch 256 mean val loss:  	0.27138057351112366
# Epoch 257 mean train loss:	0.12095143646001816
# Epoch 257 mean val loss:  	0.23683232069015503
# Epoch 258 mean train loss:	0.1195157915353775
# Epoch 258 mean val loss:  	0.296611487865448
# Epoch 259 mean train loss:	0.11529366672039032
# Epoch 259 mean val loss:  	0.26951864361763
# Epoch 260 mean train loss:	0.12417533248662949
# Epoch 260 mean val loss:  	0.2997671067714691
# Epoch 261 mean train loss:	0.11742639541625977
# Epoch 261 mean val loss:  	0.286777526140213
# Epoch 262 mean train loss:	0.1164194867014885
# Epoch 262 mean val loss:  	0.27001720666885376
# Epoch 263 mean train loss:	0.1349572390317917
# Epoch 263 mean val loss:  	0.3507802188396454
# Epoch 264 mean train loss:	0.12492147833108902
# Epoch 264 mean val loss:  	0.26817700266838074
# Epoch 265 mean train loss:	0.12511582672595978
# Epoch 265 mean val loss:  	0.39500126242637634
# Epoch 266 mean train loss:	0.12358223646879196
# Epoch 266 mean val loss:  	0.27974075078964233
# Epoch 267 mean train loss:	0.1252744495868683
# Epoch 267 mean val loss:  	0.31290674209594727
# Epoch 268 mean train loss:	0.10382551699876785
# Epoch 268 mean val loss:  	0.26615646481513977
# Epoch 269 mean train loss:	0.11458029597997665
# Epoch 269 mean val loss:  	0.29116278886795044
# Epoch 270 mean train loss:	0.1098022386431694
# Epoch 270 mean val loss:  	0.2584683895111084
# Epoch 271 mean train loss:	0.10121838003396988
# Epoch 271 mean val loss:  	0.31461092829704285
# Epoch 272 mean train loss:	0.10370685905218124
# Epoch 272 mean val loss:  	0.27959781885147095
# Epoch 273 mean train loss:	0.11106102168560028
# Epoch 273 mean val loss:  	0.26928776502609253
# Epoch 274 mean train loss:	0.10339930653572083
# Epoch 274 mean val loss:  	0.2981725037097931
# Epoch 275 mean train loss:	0.10539235174655914
# Epoch 275 mean val loss:  	0.32575422525405884
# Epoch 276 mean train loss:	0.10674543678760529
# Epoch 276 mean val loss:  	0.307956337928772
# Epoch 277 mean train loss:	0.11146148294210434
# Epoch 277 mean val loss:  	0.3818832039833069
# Epoch 278 mean train loss:	0.11109810322523117
# Epoch 278 mean val loss:  	0.25764355063438416
# Epoch 279 mean train loss:	0.1137472540140152
# Epoch 279 mean val loss:  	0.40461277961730957
# Epoch 280 mean train loss:	0.11484074592590332
# Epoch 280 mean val loss:  	0.2206728160381317
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl
# Epoch 281 mean train loss:	0.10740161687135696
# Epoch 281 mean val loss:  	0.2664087414741516
# Epoch 282 mean train loss:	0.10197955369949341
# Epoch 282 mean val loss:  	0.289352148771286
# Epoch 283 mean train loss:	0.10802444070577621
# Epoch 283 mean val loss:  	0.3359614908695221
# Epoch 284 mean train loss:	0.10631438344717026
# Epoch 284 mean val loss:  	0.31297963857650757
# Epoch 285 mean train loss:	0.11435618251562119
# Epoch 285 mean val loss:  	0.3077574372291565
# Epoch 286 mean train loss:	0.11136352270841599
# Epoch 286 mean val loss:  	0.25326666235923767
# Epoch 287 mean train loss:	0.10988490283489227
# Epoch 287 mean val loss:  	0.28669217228889465
# Epoch 288 mean train loss:	0.10444645583629608
# Epoch 288 mean val loss:  	0.25525617599487305
# Epoch 289 mean train loss:	0.09958347678184509
# Epoch 289 mean val loss:  	0.26863572001457214
# Epoch 290 mean train loss:	0.10624107718467712
# Epoch 290 mean val loss:  	0.29735496640205383
# Epoch 291 mean train loss:	0.11713401973247528
# Epoch 291 mean val loss:  	0.32415658235549927
# Epoch 292 mean train loss:	0.1116790696978569
# Epoch 292 mean val loss:  	0.3176147937774658
# Epoch 293 mean train loss:	0.11287062615156174
# Epoch 293 mean val loss:  	0.246116504073143
# Epoch 294 mean train loss:	0.10509516298770905
# Epoch 294 mean val loss:  	0.279798686504364
# Epoch 295 mean train loss:	0.13129457831382751
# Epoch 295 mean val loss:  	0.27457529306411743
# Epoch 296 mean train loss:	0.1218980923295021
# Epoch 296 mean val loss:  	0.34713876247406006
# Epoch 297 mean train loss:	0.1293824464082718
# Epoch 297 mean val loss:  	0.2473684847354889
# Epoch 298 mean train loss:	0.11517011374235153
# Epoch 298 mean val loss:  	0.271382212638855
# Epoch 299 mean train loss:	0.11291956156492233
# Epoch 299 mean val loss:  	0.3004595637321472
# Epoch 300 mean train loss:	0.10596016049385071
# Epoch 300 mean val loss:  	0.2772460877895355
# Epoch 301 mean train loss:	0.10636360943317413
# Epoch 301 mean val loss:  	0.3295285701751709
# Epoch 302 mean train loss:	0.10547580569982529
# Epoch 302 mean val loss:  	0.2824331820011139
# Epoch 303 mean train loss:	0.1062396690249443
# Epoch 303 mean val loss:  	0.29148638248443604
# Epoch 304 mean train loss:	0.09973165392875671
# Epoch 304 mean val loss:  	0.2564510703086853
# Epoch 305 mean train loss:	0.09483196586370468
# Epoch 305 mean val loss:  	0.4011250138282776
# Epoch 306 mean train loss:	0.09945801645517349
# Epoch 306 mean val loss:  	0.31842243671417236
# Epoch 307 mean train loss:	0.10135555267333984
# Epoch 307 mean val loss:  	0.25933021306991577
# Epoch 308 mean train loss:	0.10793571174144745
# Epoch 308 mean val loss:  	0.3313339650630951
# Epoch 309 mean train loss:	0.10106033086776733
# Epoch 309 mean val loss:  	0.2937184274196625
# Epoch 310 mean train loss:	0.10677645355463028
# Epoch 310 mean val loss:  	0.27919575572013855
# Epoch 311 mean train loss:	0.10023120045661926
# Epoch 311 mean val loss:  	0.2867960035800934
# Epoch 312 mean train loss:	0.10710825771093369
# Epoch 312 mean val loss:  	0.29827868938446045
# Epoch 313 mean train loss:	0.10137002170085907
# Epoch 313 mean val loss:  	0.29746514558792114
# Epoch 314 mean train loss:	0.10199113190174103
# Epoch 314 mean val loss:  	0.3257905840873718
# Epoch 315 mean train loss:	0.10957571864128113
# Epoch 315 mean val loss:  	0.2646462023258209
# Epoch 316 mean train loss:	0.10121876746416092
# Epoch 316 mean val loss:  	0.3509455919265747
# Epoch 317 mean train loss:	0.10915593057870865
# Epoch 317 mean val loss:  	0.33712688088417053
# Epoch 318 mean train loss:	0.10223737359046936
# Epoch 318 mean val loss:  	0.34068506956100464
# Epoch 319 mean train loss:	0.1069338396191597
# Epoch 319 mean val loss:  	0.2911645174026489
# Epoch 320 mean train loss:	0.10277616232633591
# Epoch 320 mean val loss:  	0.27996140718460083
# Epoch 321 mean train loss:	0.10560417920351028
# Epoch 321 mean val loss:  	0.26001396775245667
# Epoch 322 mean train loss:	0.1023155152797699
# Epoch 322 mean val loss:  	0.2908613979816437
# Epoch 323 mean train loss:	0.10052020847797394
# Epoch 323 mean val loss:  	0.311009019613266
# Epoch 324 mean train loss:	0.10754548013210297
# Epoch 324 mean val loss:  	0.29989662766456604
# Epoch 325 mean train loss:	0.11246314644813538
# Epoch 325 mean val loss:  	0.26909542083740234
# Epoch 326 mean train loss:	0.111502505838871
# Epoch 326 mean val loss:  	0.23611098527908325
# Epoch 327 mean train loss:	0.10519050061702728
# Epoch 327 mean val loss:  	0.32308125495910645
# Epoch 328 mean train loss:	0.10127347707748413
# Epoch 328 mean val loss:  	0.2727051377296448
# Epoch 329 mean train loss:	0.10237884521484375
# Epoch 329 mean val loss:  	0.26635512709617615
# Epoch 330 mean train loss:	0.10483013838529587
# Epoch 330 mean val loss:  	0.32914406061172485
# Epoch 331 mean train loss:	0.11251822113990784
# Epoch 331 mean val loss:  	0.2826783061027527
# Epoch 332 mean train loss:	0.12317466735839844
# Epoch 332 mean val loss:  	0.28434962034225464
# Epoch 333 mean train loss:	0.11012909561395645
# Epoch 333 mean val loss:  	0.28075021505355835
# Epoch 334 mean train loss:	0.10774994641542435
# Epoch 334 mean val loss:  	0.2951700687408447
# Epoch 335 mean train loss:	0.10165803879499435
# Epoch 335 mean val loss:  	0.3034490942955017
# Epoch 336 mean train loss:	0.10060600936412811
# Epoch 336 mean val loss:  	0.3092922568321228
# Epoch 337 mean train loss:	0.10171760618686676
# Epoch 337 mean val loss:  	0.3205473721027374
# Epoch 338 mean train loss:	0.11225063353776932
# Epoch 338 mean val loss:  	0.27598220109939575
# Epoch 339 mean train loss:	0.10474996268749237
# Epoch 339 mean val loss:  	0.30885979533195496
# Epoch 340 mean train loss:	0.09941959381103516
# Epoch 340 mean val loss:  	0.2432684600353241
# Epoch 341 mean train loss:	0.09897280484437943
# Epoch 341 mean val loss:  	0.24029482901096344
# Epoch 342 mean train loss:	0.10492011904716492
# Epoch 342 mean val loss:  	0.27692103385925293
# Epoch 343 mean train loss:	0.09443478286266327
# Epoch 343 mean val loss:  	0.33149731159210205
# Epoch 344 mean train loss:	0.09388664364814758
# Epoch 344 mean val loss:  	0.2646002173423767
# Epoch 345 mean train loss:	0.09324172139167786
# Epoch 345 mean val loss:  	0.32532426714897156
# Epoch 346 mean train loss:	0.09736360609531403
# Epoch 346 mean val loss:  	0.47024887800216675
# Epoch 347 mean train loss:	0.08885391056537628
# Epoch 347 mean val loss:  	0.26553791761398315
# Epoch 348 mean train loss:	0.09519336372613907
# Epoch 348 mean val loss:  	0.2869080603122711
# Epoch 349 mean train loss:	0.09592428803443909
# Epoch 349 mean val loss:  	0.39296239614486694
# Epoch 350 mean train loss:	0.09437640756368637
# Epoch 350 mean val loss:  	0.23733597993850708
# Epoch 351 mean train loss:	0.09356817603111267
# Epoch 351 mean val loss:  	0.22995184361934662
# Epoch 352 mean train loss:	0.10225281864404678
# Epoch 352 mean val loss:  	0.3774758279323578
# Epoch 353 mean train loss:	0.09355924278497696
# Epoch 353 mean val loss:  	0.27091699838638306
# Epoch 354 mean train loss:	0.0995156541466713
# Epoch 354 mean val loss:  	0.27551695704460144
# Epoch 355 mean train loss:	0.09680479764938354
# Epoch 355 mean val loss:  	0.3069843649864197
# Epoch 356 mean train loss:	0.10582146048545837
# Epoch 356 mean val loss:  	0.2926257252693176
# Epoch 357 mean train loss:	0.09138517081737518
# Epoch 357 mean val loss:  	0.28144699335098267
# Epoch 358 mean train loss:	0.08786652237176895
# Epoch 358 mean val loss:  	0.2614824175834656
# Epoch 359 mean train loss:	0.0963454395532608
# Epoch 359 mean val loss:  	0.27848196029663086
# Epoch 360 mean train loss:	0.0944487452507019
# Epoch 360 mean val loss:  	0.31944286823272705
# Epoch 361 mean train loss:	0.09537016600370407
# Epoch 361 mean val loss:  	0.24310007691383362
# Epoch 362 mean train loss:	0.0885196402668953
# Epoch 362 mean val loss:  	0.3022068738937378
# Epoch 363 mean train loss:	0.10078736394643784
# Epoch 363 mean val loss:  	0.2567610740661621
# Epoch 364 mean train loss:	0.1149381622672081
# Epoch 364 mean val loss:  	0.28047555685043335
# Epoch 365 mean train loss:	0.10088134557008743
# Epoch 365 mean val loss:  	0.7931331396102905
# Epoch 366 mean train loss:	0.10657867789268494
# Epoch 366 mean val loss:  	0.25859418511390686
# Epoch 367 mean train loss:	0.10086865723133087
# Epoch 367 mean val loss:  	0.3133755028247833
# Epoch 368 mean train loss:	0.09468238800764084
# Epoch 368 mean val loss:  	0.28510093688964844
# Epoch 369 mean train loss:	0.08932706713676453
# Epoch 369 mean val loss:  	0.23832745850086212
# Epoch 370 mean train loss:	0.09606803208589554
# Epoch 370 mean val loss:  	0.32906726002693176
# Epoch 371 mean train loss:	0.09587421268224716
# Epoch 371 mean val loss:  	0.28796738386154175
# Epoch 372 mean train loss:	0.09307151287794113
# Epoch 372 mean val loss:  	0.2509081959724426
# Epoch 373 mean train loss:	0.09054871648550034
# Epoch 373 mean val loss:  	0.36140918731689453
# Epoch 374 mean train loss:	0.09311842173337936
# Epoch 374 mean val loss:  	0.320247083902359
# Epoch 375 mean train loss:	0.09312772750854492
# Epoch 375 mean val loss:  	0.23615173995494843
# Epoch 376 mean train loss:	0.0956408753991127
# Epoch 376 mean val loss:  	0.23970471322536469
# Epoch 377 mean train loss:	0.09626598656177521
# Epoch 377 mean val loss:  	0.3217123746871948
# Epoch 378 mean train loss:	0.09174928814172745
# Epoch 378 mean val loss:  	0.345505952835083
# Epoch 379 mean train loss:	0.10050833970308304
# Epoch 379 mean val loss:  	0.26672762632369995
# Epoch 380 mean train loss:	0.1063646525144577
# Epoch 380 mean val loss:  	0.31237295269966125
# Epoch 381 mean train loss:	0.09549456089735031
# Epoch 381 mean val loss:  	0.24236036837100983
# Epoch 382 mean train loss:	0.10011302679777145
# Epoch 382 mean val loss:  	0.29019033908843994
# Epoch 383 mean train loss:	0.10060491412878036
# Epoch 383 mean val loss:  	0.2899991273880005
# Epoch 384 mean train loss:	0.09714151918888092
# Epoch 384 mean val loss:  	0.2593258321285248
# Epoch 385 mean train loss:	0.08269966393709183
# Epoch 385 mean val loss:  	0.27012157440185547
# Epoch 386 mean train loss:	0.08758001774549484
# Epoch 386 mean val loss:  	0.23647236824035645
# Epoch 387 mean train loss:	0.08493901044130325
# Epoch 387 mean val loss:  	0.28201285004615784
# Epoch 388 mean train loss:	0.09955183416604996
# Epoch 388 mean val loss:  	0.2803347706794739
# Epoch 389 mean train loss:	0.09303726255893707
# Epoch 389 mean val loss:  	0.29905539751052856
# Epoch 390 mean train loss:	0.0895157903432846
# Epoch 390 mean val loss:  	0.2588244080543518
# Epoch 391 mean train loss:	0.086378313601017
# Epoch 391 mean val loss:  	0.3180720806121826
# Epoch 392 mean train loss:	0.08313105255365372
# Epoch 392 mean val loss:  	0.24267850816249847
# Epoch 393 mean train loss:	0.08687138557434082
# Epoch 393 mean val loss:  	0.25051769614219666
# Epoch 394 mean train loss:	0.08921004086732864
# Epoch 394 mean val loss:  	0.2475716769695282
# Epoch 395 mean train loss:	0.09544909745454788
# Epoch 395 mean val loss:  	0.2836751341819763
# Epoch 396 mean train loss:	0.08472767472267151
# Epoch 396 mean val loss:  	0.28995856642723083
# Epoch 397 mean train loss:	0.09458985179662704
# Epoch 397 mean val loss:  	0.2736053466796875
# Epoch 398 mean train loss:	0.0998048335313797
# Epoch 398 mean val loss:  	0.3308348059654236
# Epoch 399 mean train loss:	0.08919870108366013
# Epoch 399 mean val loss:  	0.24780097603797913
# Epoch 400 mean train loss:	0.0864289402961731
# Epoch 400 mean val loss:  	0.27627941966056824
# Epoch 401 mean train loss:	0.0882398933172226
# Epoch 401 mean val loss:  	0.34099748730659485
# Epoch 402 mean train loss:	0.09014185518026352
# Epoch 402 mean val loss:  	0.27733904123306274
# Epoch 403 mean train loss:	0.08799847960472107
# Epoch 403 mean val loss:  	0.22457334399223328
# Epoch 404 mean train loss:	0.0901416689157486
# Epoch 404 mean val loss:  	0.22667363286018372
# Epoch 405 mean train loss:	0.0848037526011467
# Epoch 405 mean val loss:  	0.220504492521286
# Epoch 406 mean train loss:	0.08944842964410782
# Epoch 406 mean val loss:  	0.2613593637943268
# Epoch 407 mean train loss:	0.08860530704259872
# Epoch 407 mean val loss:  	0.2730432152748108
# Epoch 408 mean train loss:	0.08873172104358673
# Epoch 408 mean val loss:  	0.2323058843612671
# Epoch 409 mean train loss:	0.09196611493825912
# Epoch 409 mean val loss:  	0.2300858050584793
# Epoch 410 mean train loss:	0.09013086557388306
# Epoch 410 mean val loss:  	0.2984286844730377
# Epoch 411 mean train loss:	0.09140726923942566
# Epoch 411 mean val loss:  	0.27804815769195557
# Epoch 412 mean train loss:	0.08934444189071655
# Epoch 412 mean val loss:  	0.23607805371284485
# Epoch 413 mean train loss:	0.08757615089416504
# Epoch 413 mean val loss:  	0.2873342037200928
# Epoch 414 mean train loss:	0.09747345000505447
# Epoch 414 mean val loss:  	0.25330495834350586
# Epoch 415 mean train loss:	0.08854854851961136
# Epoch 415 mean val loss:  	0.24053087830543518
# Epoch 416 mean train loss:	0.09209746867418289
# Epoch 416 mean val loss:  	0.24442043900489807
# Epoch 417 mean train loss:	0.08824978023767471
# Epoch 417 mean val loss:  	0.2678958773612976
# Epoch 418 mean train loss:	0.08594172447919846
# Epoch 418 mean val loss:  	0.2600642442703247
# Epoch 419 mean train loss:	0.08558560162782669
# Epoch 419 mean val loss:  	0.24098697304725647
# Epoch 420 mean train loss:	0.08682829886674881
# Epoch 420 mean val loss:  	0.2643570601940155
# Epoch 421 mean train loss:	0.0887758880853653
# Epoch 421 mean val loss:  	0.24065497517585754
# Epoch 422 mean train loss:	0.08395205438137054
# Epoch 422 mean val loss:  	0.26947519183158875
# Epoch 423 mean train loss:	0.09259264171123505
# Epoch 423 mean val loss:  	0.2457282990217209
# Epoch 424 mean train loss:	0.08341800421476364
# Epoch 424 mean val loss:  	0.260873019695282
# Epoch 425 mean train loss:	0.08165201544761658
# Epoch 425 mean val loss:  	0.28024938702583313
# Epoch 426 mean train loss:	0.09443349391222
# Epoch 426 mean val loss:  	0.2843434810638428
# Epoch 427 mean train loss:	0.09002925455570221
# Epoch 427 mean val loss:  	0.27409300208091736
# Epoch 428 mean train loss:	0.08752800524234772
# Epoch 428 mean val loss:  	0.2724789083003998
# Epoch 429 mean train loss:	0.08351384103298187
# Epoch 429 mean val loss:  	0.2826492190361023
# Epoch 430 mean train loss:	0.0801449790596962
# Epoch 430 mean val loss:  	0.28786569833755493
# Epoch 431 mean train loss:	0.08183277398347855
# Epoch 431 mean val loss:  	0.34347566962242126
# Epoch 432 mean train loss:	0.09238151460886002
# Epoch 432 mean val loss:  	0.2681083083152771
# Epoch 433 mean train loss:	0.08634053170681
# Epoch 433 mean val loss:  	0.23133015632629395
# Epoch 434 mean train loss:	0.0842868760228157
# Epoch 434 mean val loss:  	0.26899513602256775
# Epoch 435 mean train loss:	0.0840868130326271
# Epoch 435 mean val loss:  	0.238397479057312
# Epoch 436 mean train loss:	0.07737118005752563
# Epoch 436 mean val loss:  	0.2358490228652954
# Epoch 437 mean train loss:	0.07634613662958145
# Epoch 437 mean val loss:  	0.26648229360580444
# Epoch 438 mean train loss:	0.08319882303476334
# Epoch 438 mean val loss:  	0.3031505346298218
# Epoch 439 mean train loss:	0.08303594589233398
# Epoch 439 mean val loss:  	0.23157572746276855
# Epoch 440 mean train loss:	0.09110216796398163
# Epoch 440 mean val loss:  	0.23039688169956207
# Epoch 441 mean train loss:	0.07896643877029419
# Epoch 441 mean val loss:  	0.3077217936515808
# Epoch 442 mean train loss:	0.08558794111013412
# Epoch 442 mean val loss:  	0.2558343708515167
# Epoch 443 mean train loss:	0.07703287154436111
# Epoch 443 mean val loss:  	0.2923107445240021
# Epoch 444 mean train loss:	0.08086276054382324
# Epoch 444 mean val loss:  	0.3198375701904297
# Epoch 445 mean train loss:	0.082956962287426
# Epoch 445 mean val loss:  	0.24686266481876373
# Epoch 446 mean train loss:	0.0864815041422844
# Epoch 446 mean val loss:  	0.25908127427101135
# Epoch 447 mean train loss:	0.09001022577285767
# Epoch 447 mean val loss:  	0.28245270252227783
# Epoch 448 mean train loss:	0.0879470482468605
# Epoch 448 mean val loss:  	0.2467452585697174
# Epoch 449 mean train loss:	0.07969675958156586
# Epoch 449 mean val loss:  	0.22385041415691376
# Epoch 450 mean train loss:	0.08810245245695114
# Epoch 450 mean val loss:  	0.2588811218738556
# Epoch 451 mean train loss:	0.10095644742250443
# Epoch 451 mean val loss:  	0.31527918577194214
# Epoch 452 mean train loss:	0.08869263529777527
# Epoch 452 mean val loss:  	0.2541409730911255
# Epoch 453 mean train loss:	0.09358573704957962
# Epoch 453 mean val loss:  	0.29167622327804565
# Epoch 454 mean train loss:	0.08570520579814911
# Epoch 454 mean val loss:  	0.28067195415496826
# Epoch 455 mean train loss:	0.0977688878774643
# Epoch 455 mean val loss:  	0.26478710770606995
# Epoch 456 mean train loss:	0.09134573489427567
# Epoch 456 mean val loss:  	0.27480196952819824
# Epoch 457 mean train loss:	0.08922521770000458
# Epoch 457 mean val loss:  	0.27796441316604614
# Epoch 458 mean train loss:	0.08359187841415405
# Epoch 458 mean val loss:  	0.25099852681159973
# Epoch 459 mean train loss:	0.08020591735839844
# Epoch 459 mean val loss:  	0.2565613389015198
# Epoch 460 mean train loss:	0.08205072581768036
# Epoch 460 mean val loss:  	0.26360875368118286
# Epoch 461 mean train loss:	0.07346253842115402
# Epoch 461 mean val loss:  	0.23672005534172058
# Epoch 462 mean train loss:	0.07742250710725784
# Epoch 462 mean val loss:  	0.28403452038764954
# Epoch 463 mean train loss:	0.08088478446006775
# Epoch 463 mean val loss:  	0.30265894532203674
# Epoch 464 mean train loss:	0.0803692489862442
# Epoch 464 mean val loss:  	0.2567717134952545
# Epoch 465 mean train loss:	0.0886661633849144
# Epoch 465 mean val loss:  	0.369473934173584
# Epoch 466 mean train loss:	0.0854102224111557
# Epoch 466 mean val loss:  	0.2577497959136963
# Epoch 467 mean train loss:	0.08097248524427414
# Epoch 467 mean val loss:  	0.3190946578979492
# Epoch 468 mean train loss:	0.08026116341352463
# Epoch 468 mean val loss:  	0.3100995719432831
# Epoch 469 mean train loss:	0.07765258848667145
# Epoch 469 mean val loss:  	0.28641989827156067
# Epoch 470 mean train loss:	0.08488873392343521
# Epoch 470 mean val loss:  	0.27720096707344055
# Epoch 471 mean train loss:	0.08036314696073532
# Epoch 471 mean val loss:  	0.2704063057899475
# Epoch 472 mean train loss:	0.08124274760484695
# Epoch 472 mean val loss:  	0.2138013243675232
# Epoch 473 mean train loss:	0.08229121565818787
# Epoch 473 mean val loss:  	0.31683751940727234
# Epoch 474 mean train loss:	0.08180943131446838
# Epoch 474 mean val loss:  	0.26724860072135925
# Epoch 475 mean train loss:	0.07832367718219757
# Epoch 475 mean val loss:  	0.2884501516819
# Epoch 476 mean train loss:	0.09143294394016266
# Epoch 476 mean val loss:  	0.2532249689102173
# Epoch 477 mean train loss:	0.0870472863316536
# Epoch 477 mean val loss:  	0.281078040599823
# Epoch 478 mean train loss:	0.08014487475156784
# Epoch 478 mean val loss:  	0.27072182297706604
# Epoch 479 mean train loss:	0.07376820594072342
# Epoch 479 mean val loss:  	0.23716305196285248
# Epoch 480 mean train loss:	0.0751391351222992
# Epoch 480 mean val loss:  	0.3020765781402588
# Epoch 481 mean train loss:	0.0763586089015007
# Epoch 481 mean val loss:  	0.3605492115020752
# Patience exhausted in epoch 481. Best val-loss was 0.2206728160381317
# Using best model from epoch 280 which had loss 0.2206728160381317
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190918-101035.pkl

# %%
logger.warning('predicting')
model.eval()

predictions = []
conv_hidden_states = None
for i, test_batch in enumerate(test_dataloader):
    if not stateful_lstm:
        conv_hidden_states = None
        
    landcover_batch = landcover.repeat(test_batch['y'].shape[0],1,1,1).to(device)
    pred, conv_hidden_states = model(test_batch['x_conv'].to(device), landcover_batch, hidden_state=conv_hidden_states)
    predictions.append(pred.detach())

predictions = torch.cat(predictions).cpu()

if stateful_lstm:
    # reorder time series
    pred_indices = np.array(list(test_sampler.__iter__())).reshape(-1)
    predictions = predictions[pred_indices.argsort()]
# Out:
# 2019-09-18 11:59:31,846 - 20190918-101035 - predicting

# %%
actuals = test_dataset.data_runoff.copy()
if len(actuals['date'].unique()) != len(predictions):
    print('Warning: length of prediction {} and actuals {} does not match.'.format(len(predictions), len(actuals['date'].unique())))

nse_list = []
mse_list = []
predictions_df = pd.DataFrame(columns=actuals.columns)
for station in actuals['station'].unique():
    row, col = test_dataset.station_to_index[station]
    
    act = actuals[actuals['station'] == station].set_index('date')['runoff']
    if predictions.shape[0] < act.shape[0]:
        print('Warning: length of prediction {} and actuals {} does not match for station {}. Ignoring excess actuals.'.format(len(predictions), len(act), station))
        act = act.iloc[:predictions.shape[0]]
    if predictions.shape[0] > act.shape[0]:
        print('Warning: length of prediction {} and actuals {} does not match for station {}. Ignoring excess predictions. (Likely this station had nan ground truth values)'.format(len(predictions), len(act), station))
    pred = pd.DataFrame({'runoff': predictions[:,row,col]}, index=test_dataset.dates)
    pred = pred.loc[act.index]
    pred['station'] = station
    predictions_df = predictions_df.append(pred.reset_index(), sort=True)
    
    nse, mse = evaluate.evaluate_daily(station, pred['runoff'], act, writer=writer)
    nse_list.append(nse)
    mse_list.append(mse)
    
    print(station, '\tNSE:', nse, '\tMSE:', mse, '(clipped to 0)')

print('Median NSE (clipped to 0)', np.median(nse_list), '/ Min', np.min(nse_list), '/ Max', np.max(nse_list))
print('Median MSE (clipped to 0)', np.median(mse_list), '/ Min', np.min(mse_list), '/ Max', np.max(mse_list))
writer.add_scalar('nse_median', np.median(nse_list))
# Out:
# /home/mgauch/miniconda3/envs/gwf/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# 04213500 	NSE: 0.7263115980296608 	MSE: 243.41965100430542 (clipped to 0)
# 04209000 	NSE: 0.7530666085969983 	MSE: 114.77398913006114 (clipped to 0)
# 04164000 	NSE: 0.6364285800284688 	MSE: 58.37160974024562 (clipped to 0)
# 04159900 	NSE: 0.6948011369782368 	MSE: 10.324595350557997 (clipped to 0)
# 04200500 	NSE: 0.745806211134633 	MSE: 259.72045186668277 (clipped to 0)
# 04160600 	NSE: 0.7536512906285575 	MSE: 6.85266340661191 (clipped to 0)
# 04208504 	NSE: 0.801712743546145 	MSE: 286.6069410850281 (clipped to 0)
# 04199500 	NSE: 0.7617671006478335 	MSE: 113.73614904523686 (clipped to 0)
# 02GG002 	NSE: 0.6918097304901092 	MSE: 59.7301609964045 (clipped to 0)
# 02GA038 	NSE: 0.5610986649989067 	MSE: 50.143896999096675 (clipped to 0)
# 04196800 	NSE: 0.7956133064955655 	MSE: 61.88854644914132 (clipped to 0)
# 04212100 	NSE: 0.8088361429156594 	MSE: 390.41519694535316 (clipped to 0)
# 04174500 	NSE: 0.6740094432856547 	MSE: 51.23844546049821 (clipped to 0)
# 02GG003 	NSE: 0.7484604031082476 	MSE: 116.17859601115558 (clipped to 0)
# 02GG006 	NSE: 0.7304422926857894 	MSE: 15.031883438167137 (clipped to 0)
# 02GA018 	NSE: 0.5996161396280767 	MSE: 72.55568075931139 (clipped to 0)
# 04161820 	NSE: 0.644169325910651 	MSE: 12.4900830427846 (clipped to 0)
# 04166500 	NSE: 0.3637121235831293 	MSE: 31.016486771492247 (clipped to 0)
# 04177000 	NSE: 0.7908540416875952 	MSE: 9.836914509933584 (clipped to 0)
# 04159492 	NSE: 0.6135592824994546 	MSE: 131.64858993677697 (clipped to 0)
# Warning: length of prediction 1818 and actuals 1774 does not match for station 02GC018. Ignoring excess predictions. (Likely this station had nan ground truth values)
# 02GC018 	NSE: 0.7133538202214365 	MSE: 20.122937762934626 (clipped to 0)
# 04199000 	NSE: 0.7139435540688936 	MSE: 285.770892737818 (clipped to 0)
# 02GA047 	NSE: 0.5308366039063166 	MSE: 30.88672942174215 (clipped to 0)
# 04193500 	NSE: 0.7785789765660496 	MSE: 17888.942078875807 (clipped to 0)
# 02GD004 	NSE: 0.6960418005515936 	MSE: 13.316249842091116 (clipped to 0)
# 02GG009 	NSE: 0.69475616506315 	MSE: 46.25476448832644 (clipped to 0)
# 04207200 	NSE: 0.7606501849829489 	MSE: 7.721732903605003 (clipped to 0)
# Warning: length of prediction 1818 and actuals 1787 does not match for station 02GG013. Ignoring excess predictions. (Likely this station had nan ground truth values)
# 02GG013 	NSE: 0.7238032083509887 	MSE: 11.1489567238367 (clipped to 0)
# 04176500 	NSE: 0.7153360347502246 	MSE: 314.62158798566463 (clipped to 0)
# 04197100 	NSE: 0.8117525313593641 	MSE: 22.763132878258368 (clipped to 0)
# 02GC007 	NSE: 0.665836834781651 	MSE: 9.332308628797547 (clipped to 0)
# 02GB001 	NSE: 0.4655071923380323 	MSE: 2879.642326440283 (clipped to 0)
# 02GA010 	NSE: 0.5712955694627239 	MSE: 143.45007295010984 (clipped to 0)
# 04213000 	NSE: 0.7669376612045268 	MSE: 50.01093570225143 (clipped to 0)
# 04215000 	NSE: 0.5961374596396014 	MSE: 34.85083975038211 (clipped to 0)
# 02GC002 	NSE: 0.7117728362637101 	MSE: 33.097455405107816 (clipped to 0)
# 04165500 	NSE: -0.015931393137812666 	MSE: 470.5268688376144 (clipped to 0)
# 04198000 	NSE: 0.7904599664050711 	MSE: 1483.271761220807 (clipped to 0)
# 02GC026 	NSE: 0.6753068541697231 	MSE: 42.70556259627047 (clipped to 0)
# 02GB007 	NSE: 0.7041079686539036 	MSE: 9.525795954204376 (clipped to 0)
# 04166100 	NSE: 0.7123907656965522 	MSE: 2.6465679582903054 (clipped to 0)
# 02GC010 	NSE: 0.6513064251635363 	MSE: 15.877068449796454 (clipped to 0)
# 04215500 	NSE: 0.6402016606292349 	MSE: 58.54006475278524 (clipped to 0)
# 04195820 	NSE: 0.79506176305233 	MSE: 311.30498203844104 (clipped to 0)
# 02GE007 	NSE: 0.646458592836245 	MSE: 10.615374506883416 (clipped to 0)
# Warning: length of prediction 1818 and actuals 823 does not match for station 04214500. Ignoring excess predictions. (Likely this station had nan ground truth values)
# 04214500 	NSE: 0.3925456530357042 	MSE: 74.07568603526283 (clipped to 0)
# Median NSE (clipped to 0) 0.7079404024588069 / Min -0.015931393137812666 / Max 0.8117525313593641
# Median MSE (clipped to 0) 50.69117122979745 / Min 2.6465679582903054 / Max 17888.942078875807

# %%
writer.close()

# %%
save_df = pd.merge(predictions_df.rename({'runoff': 'prediction'}, axis=1), actuals.rename({'runoff': 'actual'}, axis=1), 
                   on=['date', 'station'])[['date', 'station', 'prediction', 'actual']]
load_data.pickle_results('ConvLSTM_withLandcover', save_df, time_stamp)
# Out:
# 'ConvLSTM_withLandcover_20190918-101035.pkl'

# %%
datetime.now().strftime('%Y%m%d-%H%M%S')
# Out:
# '20190918-115952'
