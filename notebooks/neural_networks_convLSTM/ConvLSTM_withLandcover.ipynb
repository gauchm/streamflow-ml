# %% [markdown]
# ConvLSTM->Conv network, trained on gridded forcing time-series and gridded geophysical data for all stations.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../..')
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
from datetime import datetime, timedelta
from sklearn import preprocessing
import netCDF4 as nc
import torch
from torch import nn, utils
from torch.utils.tensorboard import SummaryWriter
from src import load_data, evaluate, conv_lstm, datasets, utils
import torch.autograd as autograd
import pickle

time_stamp = datetime.now().strftime('%Y%m%d-%H%M%S')
time_stamp
# Out:
# '20190917-195600'

# %%
import logging
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='../../log.out', mode='a')
chandler = logging.StreamHandler(sys.stdout)
formatter = logging.Formatter('%(asctime)s - {} - %(message)s'.format(time_stamp))
fhandler.setFormatter(formatter)
chandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.addHandler(chandler)
logger.setLevel(logging.INFO)

# %%
USE_CUDA = False
if torch.cuda.is_available():
    print('CUDA Available')
    USE_CUDA = True
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
device = torch.device('cuda:0' if USE_CUDA else 'cpu')
num_devices = torch.cuda.device_count() if USE_CUDA else 0
logger.warning('cuda devices: {}'.format(list(torch.cuda.get_device_name(i) for i in range(num_devices))))
torch.manual_seed(0)
np.random.seed(0)
# Out:
# CUDA Available
# 2019-09-17 19:56:00,338 - 20190917-195600 - cuda devices: ['Tesla V100-SXM2-16GB']

# %%
seq_len = 8
seq_steps = 1
stateful_lstm = False
validation_fraction, val_start, val_end = None, None, None

if stateful_lstm:
    val_start = datetime.strptime('2010-01-01', '%Y-%m-%d') + timedelta(days=seq_len * seq_steps)  # first day for which to make a prediction in train set
    val_end = '2010-09-30'
    train_start = '2010-10-01'
    train_end = '2012-12-31'
else:
    validation_fraction = 0.1
    train_start = datetime.strptime('2010-01-01', '%Y-%m-%d') + timedelta(days=seq_len * seq_steps)  # first day for which to make a prediction in train set
    train_end = '2012-12-31'
test_start = '2010-01-09'
test_end = '2014-12-31'

# %%
rdrs_vars = [4, 5]
agg = ['sum', 'minmax']
include_month = True
train_dataset = datasets.RdrsGridDataset(rdrs_vars, seq_len, seq_steps, train_start, train_end, aggregate_daily=agg, include_months=include_month, resample_rdrs=True)
if stateful_lstm:
    val_dataset = datasets.RdrsGridDataset(rdrs_vars, seq_len, seq_steps, val_start, val_end, conv_scalers=train_dataset.conv_scalers, aggregate_daily=agg, include_months=include_month, resample_rdrs=True)
test_dataset = datasets.RdrsGridDataset(rdrs_vars, seq_len, seq_steps, test_start, test_end, conv_scalers=train_dataset.conv_scalers, aggregate_daily=agg, include_months=include_month, resample_rdrs=True)

# %%
landcover_types = None
landcover, landcover_legend = load_data.load_landcover_reduced(values_to_use=landcover_types)
landcover = torch.from_numpy(landcover).float().to(device)
# Out:
# ../../src/load_data.py:419: UserWarning: WARNING: valid_range not used since it
# cannot be safely cast to variable data type
#   landcover_fullres = np.array(landcover_nc['Band1'][:])[::-1,:]

# %%
# Train model
num_epochs = 800
learning_rate = 2e-3
patience = 200
min_improvement = 0.01
best_loss_model = (-1, np.inf, None)

# Prepare model
batch_size = 32
num_convlstm_layers = 5
num_conv_layers = 5
convlstm_hidden_dims = [128,64,64,64,32]
conv_hidden_dims = [128,128,64,32]
convlstm_kernel_size = [(3,3)] * num_convlstm_layers
conv_kernel_size = [(3,3)] * num_conv_layers
conv_activation = nn.LeakyReLU
dropout = 0.2
weight_decay = 1e-6

model = conv_lstm.ConvLSTMGridWithGeophysicalInput((train_dataset.conv_height, train_dataset.conv_width), 
                                         train_dataset.n_conv_vars, landcover.shape[0], convlstm_hidden_dims, 
                                         conv_hidden_dims, convlstm_kernel_size, conv_kernel_size, 
                                         num_convlstm_layers, num_conv_layers, conv_activation, dropout=dropout,
                                                  feed_timesteps=seq_len).to(device)
if num_devices > 1:
    model = torch.nn.DataParallel(model, device_ids=list(range(num_devices)))
loss_fn = evaluate.NSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

writer = SummaryWriter(comment='ConvLSTM_withLandcover')
param_description = {'time_stamp': time_stamp, 'H_convlstm': convlstm_hidden_dims, 'H_conv': conv_hidden_dims, 'batch_size': batch_size, 'num_convlstm_layers': num_convlstm_layers, 'num_conv_layers': num_conv_layers, 'convlstm_kernel_size': convlstm_kernel_size, 'conv_kernel_size': conv_kernel_size, 'loss': loss_fn, 
                     'optimizer': optimizer, 'lr': learning_rate, 'patience': patience, 'min_improvement': min_improvement, 'stateful_lstm': stateful_lstm, 'dropout': dropout, 'landcover_shape': landcover.shape, 'conv_activation': conv_activation,
                     'num_epochs': num_epochs, 'seq_len': seq_len, 'seq_steps': seq_steps, 'train_start': train_start, 'train_end': train_end, 'weight_decay': weight_decay, 'validation_fraction': validation_fraction, 'landcover_types': landcover_types,
                     'test_start': test_start, 'test_end': test_end, 'n_conv_vars': train_dataset.n_conv_vars, 'model': str(model).replace('\n','').replace(' ', ''), 'val_start': val_start, 'val_end': val_end, 'aggregate_daily': agg,
                     'train len':len(train_dataset), 'conv_height': train_dataset.conv_height, 'conv_width': train_dataset.conv_width, 'test len': len(test_dataset), 'include_month': include_month}
writer.add_text('Parameter Description', str(param_description))
str(param_description)
# Out:
# "{'time_stamp': '20190917-195600', 'H_convlstm': [128, 64, 64, 64, 32], 'H_conv': [128, 128, 64, 32], 'batch_size': 32, 'num_convlstm_layers': 5, 'num_conv_layers': 5, 'convlstm_kernel_size': [(3, 3), (3, 3), (3, 3), (3, 3), (3, 3)], 'conv_kernel_size': [(3, 3), (3, 3), (3, 3), (3, 3), (3, 3)], 'loss': NSELoss(), 'optimizer': Adam (\nParameter Group 0\n    amsgrad: False\n    betas: (0.9, 0.999)\n    eps: 1e-08\n    lr: 0.002\n    weight_decay: 1e-06\n), 'lr': 0.002, 'patience': 200, 'min_improvement': 0.01, 'stateful_lstm': False, 'dropout': 0.2, 'landcover_shape': torch.Size([19, 34, 39]), 'conv_activation': <class 'torch.nn.modules.activation.LeakyReLU'>, 'num_epochs': 800, 'seq_len': 8, 'seq_steps': 1, 'train_start': datetime.datetime(2010, 1, 9, 0, 0), 'train_end': '2012-12-31', 'weight_decay': 1e-06, 'validation_fraction': 0.1, 'landcover_types': None, 'test_start': '2010-01-09', 'test_end': '2014-12-31', 'n_conv_vars': 15, 'model': 'ConvLSTMGridWithGeophysicalInput((conv_lstm):ConvLSTM((cell_list):ModuleList((0):ConvLSTMCell((conv):Conv2d(143,512,kernel_size=(3,3),stride=(1,1),padding=(1,1)))(1):Identity()(2):ConvLSTMCell((conv):Conv2d(192,256,kernel_size=(3,3),stride=(1,1),padding=(1,1)))(3):Identity()(4):ConvLSTMCell((conv):Conv2d(128,256,kernel_size=(3,3),stride=(1,1),padding=(1,1)))(5):Identity()(6):ConvLSTMCell((conv):Conv2d(128,256,kernel_size=(3,3),stride=(1,1),padding=(1,1)))(7):Identity()(8):ConvLSTMCell((conv):Conv2d(96,128,kernel_size=(3,3),stride=(1,1),padding=(1,1)))(9):Identity()))(dropout):Dropout2d(p=0.2,inplace=False)(upsample):Identity()(conv_out):Sequential((0):BatchNorm2d(275,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)(1):Conv2d(275,128,kernel_size=(3,3),stride=(1,1),padding=(1,1))(2):Dropout(p=0.2,inplace=False)(3):LeakyReLU(negative_slope=0.01)(4):BatchNorm2d(128,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)(5):Conv2d(128,128,kernel_size=(3,3),stride=(1,1),padding=(1,1))(6):LeakyReLU(negative_slope=0.01)(7):Dropout2d(p=0.2,inplace=False)(8):BatchNorm2d(128,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)(9):Conv2d(128,64,kernel_size=(3,3),stride=(1,1),padding=(1,1))(10):LeakyReLU(negative_slope=0.01)(11):Dropout2d(p=0.2,inplace=False)(12):BatchNorm2d(64,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)(13):Conv2d(64,32,kernel_size=(3,3),stride=(1,1),padding=(1,1))(14):LeakyReLU(negative_slope=0.01)(15):Dropout2d(p=0.2,inplace=False)(16):BatchNorm2d(32,eps=1e-05,momentum=0.1,affine=True,track_running_stats=True)(17):Conv2d(32,1,kernel_size=(3,3),stride=(1,1),padding=(1,1))))', 'val_start': None, 'val_end': None, 'aggregate_daily': ['sum', 'minmax'], 'train len': 1088, 'conv_height': 34, 'conv_width': 39, 'test len': 1818, 'include_month': True}"

# %%
if stateful_lstm:
    train_sampler = datasets.StatefulBatchSampler(train_dataset, batch_size)
    val_sampler = datasets.StatefulBatchSampler(val_dataset, batch_size)
    test_sampler = datasets.StatefulBatchSampler(test_dataset, batch_size)
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_sampler=train_sampler, pin_memory=True)
    val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_sampler=val_sampler, pin_memory=True)
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_sampler=test_sampler, pin_memory=True)
else:
    val_indices = np.random.choice(len(train_dataset), size=int(validation_fraction * len(train_dataset)), replace=False)
    train_indices = list(i for i in range(len(train_dataset)) if i not in val_indices)
    train_sampler = torch.utils.data.SubsetRandomSampler(train_indices)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_indices)
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, sampler=train_sampler, pin_memory=True, drop_last=False)
    val_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, sampler=val_sampler, pin_memory=True, drop_last=False)
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size, shuffle=False, pin_memory=True, drop_last=False)

# %%
torch.manual_seed(0)
np.random.seed(0)
for epoch in range(num_epochs):
    model.train()

    epoch_losses = torch.tensor(0.0)
    conv_hidden_states = None
    train_means = train_dataset.y_means.reshape(-1).to(device)
    for i, train_batch in enumerate(train_dataloader):
        y_train = train_batch['y'].reshape((train_batch['y'].shape[0],-1)).to(device, non_blocking=True)
        mask = train_batch['mask'].any(dim=0).reshape(-1).to(device, non_blocking=True)
        landcover_batch = landcover.repeat(y_train.shape[0],1,1,1).to(device)
        
        if not mask.any():
            print('Batch {} has no target values. skipping.'.format(i))
            continue
        if not stateful_lstm:
            conv_hidden_states = None
        
        y_pred, conv_hidden_states = model(train_batch['x_conv'].to(device), landcover_batch, hidden_state=conv_hidden_states)
        y_pred = y_pred.reshape((train_batch['y'].shape[0], -1))
        loss = loss_fn(y_pred[:,mask], y_train[:,mask], means=train_means[mask])

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        epoch_losses += loss.detach()
        
    epoch_loss = (epoch_losses / len(train_dataloader)).item()
    print('Epoch', epoch, 'mean train loss:\t{}'.format(epoch_loss))
    writer.add_scalar('loss_nse', epoch_loss, epoch)
    
    # eval on validation split
    model.eval()
    val_losses = torch.tensor(0.0)
    conv_hidden_states = None
    for i, val_batch in enumerate(val_dataloader):
        y_val = val_batch['y'].reshape((val_batch['y'].shape[0],-1)).to(device, non_blocking=True)
        mask = val_batch['mask'].any(dim=0).reshape(-1).to(device, non_blocking=True)
        landcover_batch = landcover.repeat(y_val.shape[0],1,1,1).to(device)
        
        if not stateful_lstm:
            conv_hidden_states = None
        
        batch_pred, conv_hidden_states = model(val_batch['x_conv'].to(device), landcover_batch, hidden_state=conv_hidden_states)
        batch_pred = batch_pred.detach().reshape((val_batch['y'].shape[0], -1))
        val_losses += loss_fn(batch_pred[:,mask], y_val[:,mask], means=train_means[mask]).detach()
        
    val_nse = (val_losses / len(val_dataloader)).item()
    print('Epoch {} mean val loss:  \t{}'.format(epoch, val_nse))
    writer.add_scalar('loss_nse_val', val_nse, epoch)
    if val_nse < best_loss_model[1] - min_improvement:
        best_loss_model = (epoch, val_nse, model.state_dict())  # new best model
        load_data.pickle_model('ConvLSTM_withLandcover', model, 'allStations', time_stamp)
    elif epoch > best_loss_model[0] + patience:
        print('Patience exhausted in epoch {}. Best val-loss was {}'.format(epoch, best_loss_model[1]))
        break
    
print('Using best model from epoch', str(best_loss_model[0]), 'which had loss', str(best_loss_model[1]))
model.load_state_dict(best_loss_model[2])
load_data.pickle_model('ConvLSTM_withLandcover', model, 'allStations', time_stamp)
# Out:
# Epoch 0 mean train loss:	1.2413785457611084
# Epoch 0 mean val loss:  	1.175148367881775
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 1 mean train loss:	1.1512451171875
# Epoch 1 mean val loss:  	1.2575082778930664
# Epoch 2 mean train loss:	1.1322845220565796
# Epoch 2 mean val loss:  	1.1118885278701782
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 3 mean train loss:	1.079087734222412
# Epoch 3 mean val loss:  	0.991722822189331
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 4 mean train loss:	1.0566246509552002
# Epoch 4 mean val loss:  	1.0608199834823608
# Epoch 5 mean train loss:	1.0324658155441284
# Epoch 5 mean val loss:  	1.0895887613296509
# Epoch 6 mean train loss:	1.0372166633605957
# Epoch 6 mean val loss:  	1.1443407535552979
# Epoch 7 mean train loss:	1.0089805126190186
# Epoch 7 mean val loss:  	1.063859462738037
# Epoch 8 mean train loss:	1.026663899421692
# Epoch 8 mean val loss:  	0.9864484071731567
# Epoch 9 mean train loss:	0.9857656955718994
# Epoch 9 mean val loss:  	0.9578622579574585
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 10 mean train loss:	0.9524056315422058
# Epoch 10 mean val loss:  	0.9560955762863159
# Epoch 11 mean train loss:	0.9585912227630615
# Epoch 11 mean val loss:  	0.9122343063354492
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 12 mean train loss:	0.9847798347473145
# Epoch 12 mean val loss:  	0.9721160531044006
# Epoch 13 mean train loss:	0.951892077922821
# Epoch 13 mean val loss:  	0.9065580368041992
# Epoch 14 mean train loss:	0.949799120426178
# Epoch 14 mean val loss:  	0.8432332873344421
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 15 mean train loss:	0.9400378465652466
# Epoch 15 mean val loss:  	0.9229358434677124
# Epoch 16 mean train loss:	0.9317942261695862
# Epoch 16 mean val loss:  	0.9092403650283813
# Epoch 17 mean train loss:	0.9339514970779419
# Epoch 17 mean val loss:  	0.9698880314826965
# Epoch 18 mean train loss:	0.9360730648040771
# Epoch 18 mean val loss:  	0.9289592504501343
# Epoch 19 mean train loss:	0.9747996926307678
# Epoch 19 mean val loss:  	0.9612390995025635
# Epoch 20 mean train loss:	0.9488407373428345
# Epoch 20 mean val loss:  	0.9657465219497681
# Epoch 21 mean train loss:	0.9275162220001221
# Epoch 21 mean val loss:  	0.9343320727348328
# Epoch 22 mean train loss:	0.9277224540710449
# Epoch 22 mean val loss:  	0.9316181540489197
# Epoch 23 mean train loss:	0.9292061924934387
# Epoch 23 mean val loss:  	1.004955530166626
# Epoch 24 mean train loss:	0.9316622614860535
# Epoch 24 mean val loss:  	0.9031863808631897
# Epoch 25 mean train loss:	0.9148741960525513
# Epoch 25 mean val loss:  	0.9580374956130981
# Epoch 26 mean train loss:	0.9157833456993103
# Epoch 26 mean val loss:  	0.9155203700065613
# Epoch 27 mean train loss:	0.9039037823677063
# Epoch 27 mean val loss:  	0.902350902557373
# Epoch 28 mean train loss:	0.9105842709541321
# Epoch 28 mean val loss:  	0.8786378502845764
# Epoch 29 mean train loss:	0.9025083780288696
# Epoch 29 mean val loss:  	0.8551120758056641
# Epoch 30 mean train loss:	0.8933606147766113
# Epoch 30 mean val loss:  	0.9205220937728882
# Epoch 31 mean train loss:	0.8798756003379822
# Epoch 31 mean val loss:  	0.845158040523529
# Epoch 32 mean train loss:	0.8638622164726257
# Epoch 32 mean val loss:  	0.8119955062866211
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 33 mean train loss:	0.8082579970359802
# Epoch 33 mean val loss:  	0.760190486907959
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 34 mean train loss:	0.8535345792770386
# Epoch 34 mean val loss:  	0.9710817933082581
# Epoch 35 mean train loss:	0.8077844381332397
# Epoch 35 mean val loss:  	0.7252123355865479
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 36 mean train loss:	0.7695967555046082
# Epoch 36 mean val loss:  	0.7466078996658325
# Epoch 37 mean train loss:	0.748052716255188
# Epoch 37 mean val loss:  	0.6450344324111938
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 38 mean train loss:	0.7376111745834351
# Epoch 38 mean val loss:  	1.1711242198944092
# Epoch 39 mean train loss:	0.718521773815155
# Epoch 39 mean val loss:  	0.7032068371772766
# Epoch 40 mean train loss:	0.7229652404785156
# Epoch 40 mean val loss:  	0.7980924248695374
# Epoch 41 mean train loss:	0.6835477948188782
# Epoch 41 mean val loss:  	0.6929391622543335
# Epoch 42 mean train loss:	0.6917893290519714
# Epoch 42 mean val loss:  	0.6477657556533813
# Epoch 43 mean train loss:	0.6652511358261108
# Epoch 43 mean val loss:  	0.8037145733833313
# Epoch 44 mean train loss:	0.6811071038246155
# Epoch 44 mean val loss:  	1.0010579824447632
# Epoch 45 mean train loss:	0.7935826182365417
# Epoch 45 mean val loss:  	0.8706735968589783
# Epoch 46 mean train loss:	0.6717087626457214
# Epoch 46 mean val loss:  	0.5619564056396484
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 47 mean train loss:	0.6441645622253418
# Epoch 47 mean val loss:  	0.5673897862434387
# Epoch 48 mean train loss:	0.611806333065033
# Epoch 48 mean val loss:  	0.6124252676963806
# Epoch 49 mean train loss:	0.6159306168556213
# Epoch 49 mean val loss:  	0.5411505699157715
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 50 mean train loss:	0.5594010949134827
# Epoch 50 mean val loss:  	0.7475194931030273
# Epoch 51 mean train loss:	0.5841213464736938
# Epoch 51 mean val loss:  	0.5143480896949768
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 52 mean train loss:	0.5841330885887146
# Epoch 52 mean val loss:  	0.7610040903091431
# Epoch 53 mean train loss:	0.5819457173347473
# Epoch 53 mean val loss:  	0.5246325135231018
# Epoch 54 mean train loss:	0.555389940738678
# Epoch 54 mean val loss:  	0.44534748792648315
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 55 mean train loss:	0.5510985851287842
# Epoch 55 mean val loss:  	0.4873257875442505
# Epoch 56 mean train loss:	0.6049182415008545
# Epoch 56 mean val loss:  	0.5970215797424316
# Epoch 57 mean train loss:	0.5526935458183289
# Epoch 57 mean val loss:  	0.4461105167865753
# Epoch 58 mean train loss:	0.5485680103302002
# Epoch 58 mean val loss:  	0.6384297013282776
# Epoch 59 mean train loss:	0.5457450747489929
# Epoch 59 mean val loss:  	0.9720081090927124
# Epoch 60 mean train loss:	0.5357128381729126
# Epoch 60 mean val loss:  	0.5990365147590637
# Epoch 61 mean train loss:	0.5409350991249084
# Epoch 61 mean val loss:  	0.7918384671211243
# Epoch 62 mean train loss:	0.5455641150474548
# Epoch 62 mean val loss:  	0.5012136101722717
# Epoch 63 mean train loss:	0.49468445777893066
# Epoch 63 mean val loss:  	0.6130428314208984
# Epoch 64 mean train loss:	0.48339226841926575
# Epoch 64 mean val loss:  	0.38664546608924866
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 65 mean train loss:	0.4946939945220947
# Epoch 65 mean val loss:  	0.499714195728302
# Epoch 66 mean train loss:	0.46936607360839844
# Epoch 66 mean val loss:  	0.505462110042572
# Epoch 67 mean train loss:	0.46798911690711975
# Epoch 67 mean val loss:  	0.5675009489059448
# Epoch 68 mean train loss:	0.476261705160141
# Epoch 68 mean val loss:  	0.505530834197998
# Epoch 69 mean train loss:	0.4545663297176361
# Epoch 69 mean val loss:  	0.5615036487579346
# Epoch 70 mean train loss:	0.4836074113845825
# Epoch 70 mean val loss:  	0.5003727674484253
# Epoch 71 mean train loss:	0.45634564757347107
# Epoch 71 mean val loss:  	0.48402923345565796
# Epoch 72 mean train loss:	0.44507718086242676
# Epoch 72 mean val loss:  	0.5286731719970703
# Epoch 73 mean train loss:	0.47008422017097473
# Epoch 73 mean val loss:  	0.5143367648124695
# Epoch 74 mean train loss:	0.4472619295120239
# Epoch 74 mean val loss:  	0.44067075848579407
# Epoch 75 mean train loss:	0.4656490087509155
# Epoch 75 mean val loss:  	0.41799086332321167
# Epoch 76 mean train loss:	0.4457029402256012
# Epoch 76 mean val loss:  	0.4987160861492157
# Epoch 77 mean train loss:	0.4241499602794647
# Epoch 77 mean val loss:  	0.5384328365325928
# Epoch 78 mean train loss:	0.42810875177383423
# Epoch 78 mean val loss:  	0.5770673751831055
# Epoch 79 mean train loss:	0.42058855295181274
# Epoch 79 mean val loss:  	0.45424121618270874
# Epoch 80 mean train loss:	0.40953999757766724
# Epoch 80 mean val loss:  	0.43096405267715454
# Epoch 81 mean train loss:	0.4016727805137634
# Epoch 81 mean val loss:  	0.5893688201904297
# Epoch 82 mean train loss:	0.3717619478702545
# Epoch 82 mean val loss:  	0.44575923681259155
# Epoch 83 mean train loss:	0.3999421000480652
# Epoch 83 mean val loss:  	0.40086519718170166
# Epoch 84 mean train loss:	0.35625866055488586
# Epoch 84 mean val loss:  	0.47426140308380127
# Epoch 85 mean train loss:	0.395370751619339
# Epoch 85 mean val loss:  	0.4064263105392456
# Epoch 86 mean train loss:	0.37775295972824097
# Epoch 86 mean val loss:  	0.44685137271881104
# Epoch 87 mean train loss:	0.36667579412460327
# Epoch 87 mean val loss:  	0.6663992404937744
# Epoch 88 mean train loss:	0.4053603708744049
# Epoch 88 mean val loss:  	0.6308304071426392
# Epoch 89 mean train loss:	0.4039191007614136
# Epoch 89 mean val loss:  	0.9767839312553406
# Epoch 90 mean train loss:	0.388656347990036
# Epoch 90 mean val loss:  	0.4308916926383972
# Epoch 91 mean train loss:	0.3684264123439789
# Epoch 91 mean val loss:  	0.4255285859107971
# Epoch 92 mean train loss:	0.3814302980899811
# Epoch 92 mean val loss:  	0.4417186677455902
# Epoch 93 mean train loss:	0.35358962416648865
# Epoch 93 mean val loss:  	0.5317085385322571
# Epoch 94 mean train loss:	0.375121146440506
# Epoch 94 mean val loss:  	0.49104058742523193
# Epoch 95 mean train loss:	0.3679409623146057
# Epoch 95 mean val loss:  	0.5061041712760925
# Epoch 96 mean train loss:	0.36392131447792053
# Epoch 96 mean val loss:  	0.4946759343147278
# Epoch 97 mean train loss:	0.3921148180961609
# Epoch 97 mean val loss:  	0.48651307821273804
# Epoch 98 mean train loss:	0.3405548930168152
# Epoch 98 mean val loss:  	0.4169488549232483
# Epoch 99 mean train loss:	0.33215945959091187
# Epoch 99 mean val loss:  	0.4244638681411743
# Epoch 100 mean train loss:	0.3311067819595337
# Epoch 100 mean val loss:  	0.360773503780365
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 101 mean train loss:	0.3289787173271179
# Epoch 101 mean val loss:  	0.3769862949848175
# Epoch 102 mean train loss:	0.32860472798347473
# Epoch 102 mean val loss:  	0.44859811663627625
# Epoch 103 mean train loss:	0.31225699186325073
# Epoch 103 mean val loss:  	0.4338744282722473
# Epoch 104 mean train loss:	0.3424971103668213
# Epoch 104 mean val loss:  	0.3953607678413391
# Epoch 105 mean train loss:	0.35476574301719666
# Epoch 105 mean val loss:  	0.645629346370697
# Epoch 106 mean train loss:	0.3370552659034729
# Epoch 106 mean val loss:  	0.5203425288200378
# Epoch 107 mean train loss:	0.3448682725429535
# Epoch 107 mean val loss:  	0.4347171187400818
# Epoch 108 mean train loss:	0.3308633863925934
# Epoch 108 mean val loss:  	0.40064382553100586
# Epoch 109 mean train loss:	0.35841694474220276
# Epoch 109 mean val loss:  	0.3662589490413666
# Epoch 110 mean train loss:	0.32876986265182495
# Epoch 110 mean val loss:  	0.39974355697631836
# Epoch 111 mean train loss:	0.32792288064956665
# Epoch 111 mean val loss:  	0.3692300319671631
# Epoch 112 mean train loss:	0.3362468481063843
# Epoch 112 mean val loss:  	0.495904803276062
# Epoch 113 mean train loss:	0.3271435499191284
# Epoch 113 mean val loss:  	0.4349711239337921
# Epoch 114 mean train loss:	0.3317092955112457
# Epoch 114 mean val loss:  	0.38132208585739136
# Epoch 115 mean train loss:	0.3486958146095276
# Epoch 115 mean val loss:  	0.45929208397865295
# Epoch 116 mean train loss:	0.36157575249671936
# Epoch 116 mean val loss:  	0.48608800768852234
# Epoch 117 mean train loss:	0.35423555970191956
# Epoch 117 mean val loss:  	0.4563112258911133
# Epoch 118 mean train loss:	0.3273155391216278
# Epoch 118 mean val loss:  	0.4920846223831177
# Epoch 119 mean train loss:	0.3375927805900574
# Epoch 119 mean val loss:  	0.44907525181770325
# Epoch 120 mean train loss:	0.3333355486392975
# Epoch 120 mean val loss:  	0.3585187792778015
# Epoch 121 mean train loss:	0.3164040744304657
# Epoch 121 mean val loss:  	0.4413900375366211
# Epoch 122 mean train loss:	0.2942277193069458
# Epoch 122 mean val loss:  	0.40530702471733093
# Epoch 123 mean train loss:	0.3034595847129822
# Epoch 123 mean val loss:  	0.3632023334503174
# Epoch 124 mean train loss:	0.325969934463501
# Epoch 124 mean val loss:  	0.4750267267227173
# Epoch 125 mean train loss:	0.3015316426753998
# Epoch 125 mean val loss:  	0.46743500232696533
# Epoch 126 mean train loss:	0.31033995747566223
# Epoch 126 mean val loss:  	0.3825966715812683
# Epoch 127 mean train loss:	0.3018065094947815
# Epoch 127 mean val loss:  	0.4837116003036499
# Epoch 128 mean train loss:	0.28956136107444763
# Epoch 128 mean val loss:  	0.35458680987358093
# Epoch 129 mean train loss:	0.2978455722332001
# Epoch 129 mean val loss:  	0.39467453956604004
# Epoch 130 mean train loss:	0.2821621000766754
# Epoch 130 mean val loss:  	0.3973017632961273
# Epoch 131 mean train loss:	0.30171605944633484
# Epoch 131 mean val loss:  	0.4050195813179016
# Epoch 132 mean train loss:	0.29571712017059326
# Epoch 132 mean val loss:  	0.40550780296325684
# Epoch 133 mean train loss:	0.2884594798088074
# Epoch 133 mean val loss:  	0.37490466237068176
# Epoch 134 mean train loss:	0.2757149636745453
# Epoch 134 mean val loss:  	0.32088419795036316
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 135 mean train loss:	0.2725367248058319
# Epoch 135 mean val loss:  	0.3132287859916687
# Epoch 136 mean train loss:	0.2690337002277374
# Epoch 136 mean val loss:  	0.37748876214027405
# Epoch 137 mean train loss:	0.26366207003593445
# Epoch 137 mean val loss:  	0.4337925910949707
# Epoch 138 mean train loss:	0.28256186842918396
# Epoch 138 mean val loss:  	0.36148425936698914
# Epoch 139 mean train loss:	0.2804329991340637
# Epoch 139 mean val loss:  	0.44151824712753296
# Epoch 140 mean train loss:	0.3009408414363861
# Epoch 140 mean val loss:  	0.4074130654335022
# Epoch 141 mean train loss:	0.28093311190605164
# Epoch 141 mean val loss:  	0.4123355746269226
# Epoch 142 mean train loss:	0.27096715569496155
# Epoch 142 mean val loss:  	0.38799452781677246
# Epoch 143 mean train loss:	0.26156577467918396
# Epoch 143 mean val loss:  	0.351853609085083
# Epoch 144 mean train loss:	0.2657575011253357
# Epoch 144 mean val loss:  	0.371210515499115
# Epoch 145 mean train loss:	0.26177600026130676
# Epoch 145 mean val loss:  	0.3949596881866455
# Epoch 146 mean train loss:	0.2473864108324051
# Epoch 146 mean val loss:  	0.3490757346153259
# Epoch 147 mean train loss:	0.25689271092414856
# Epoch 147 mean val loss:  	0.40331220626831055
# Epoch 148 mean train loss:	0.26020440459251404
# Epoch 148 mean val loss:  	0.5139820575714111
# Epoch 149 mean train loss:	0.2729604244232178
# Epoch 149 mean val loss:  	0.3776804208755493
# Epoch 150 mean train loss:	0.27516525983810425
# Epoch 150 mean val loss:  	0.46277740597724915
# Epoch 151 mean train loss:	0.24364833533763885
# Epoch 151 mean val loss:  	0.4132745862007141
# Epoch 152 mean train loss:	0.2509787976741791
# Epoch 152 mean val loss:  	0.4030161499977112
# Epoch 153 mean train loss:	0.2436217963695526
# Epoch 153 mean val loss:  	0.36944684386253357
# Epoch 154 mean train loss:	0.2501634657382965
# Epoch 154 mean val loss:  	0.4389995038509369
# Epoch 155 mean train loss:	0.244684636592865
# Epoch 155 mean val loss:  	0.398470938205719
# Epoch 156 mean train loss:	0.24917811155319214
# Epoch 156 mean val loss:  	0.36578893661499023
# Epoch 157 mean train loss:	0.23775877058506012
# Epoch 157 mean val loss:  	0.438860684633255
# Epoch 158 mean train loss:	0.24359023571014404
# Epoch 158 mean val loss:  	0.4377013146877289
# Epoch 159 mean train loss:	0.2338600903749466
# Epoch 159 mean val loss:  	0.41799455881118774
# Epoch 160 mean train loss:	0.24017009139060974
# Epoch 160 mean val loss:  	0.3550001382827759
# Epoch 161 mean train loss:	0.2584672272205353
# Epoch 161 mean val loss:  	0.3653147220611572
# Epoch 162 mean train loss:	0.25456666946411133
# Epoch 162 mean val loss:  	0.38161027431488037
# Epoch 163 mean train loss:	0.23632127046585083
# Epoch 163 mean val loss:  	0.39593783020973206
# Epoch 164 mean train loss:	0.23864057660102844
# Epoch 164 mean val loss:  	0.38097402453422546
# Epoch 165 mean train loss:	0.23197926580905914
# Epoch 165 mean val loss:  	0.3693602681159973
# Epoch 166 mean train loss:	0.24670934677124023
# Epoch 166 mean val loss:  	0.423103392124176
# Epoch 167 mean train loss:	0.2555166482925415
# Epoch 167 mean val loss:  	0.36039406061172485
# Epoch 168 mean train loss:	0.2393530309200287
# Epoch 168 mean val loss:  	0.41289496421813965
# Epoch 169 mean train loss:	0.24491466581821442
# Epoch 169 mean val loss:  	0.3777252435684204
# Epoch 170 mean train loss:	0.2431240826845169
# Epoch 170 mean val loss:  	0.432761549949646
# Epoch 171 mean train loss:	0.22727230191230774
# Epoch 171 mean val loss:  	0.32214003801345825
# Epoch 172 mean train loss:	0.22353972494602203
# Epoch 172 mean val loss:  	0.392965167760849
# Epoch 173 mean train loss:	0.22079625725746155
# Epoch 173 mean val loss:  	0.35556530952453613
# Epoch 174 mean train loss:	0.2213623970746994
# Epoch 174 mean val loss:  	0.3619227111339569
# Epoch 175 mean train loss:	0.2040429562330246
# Epoch 175 mean val loss:  	0.36893218755722046
# Epoch 176 mean train loss:	0.22970910370349884
# Epoch 176 mean val loss:  	0.4908970296382904
# Epoch 177 mean train loss:	0.22807914018630981
# Epoch 177 mean val loss:  	0.4059092700481415
# Epoch 178 mean train loss:	0.21607735753059387
# Epoch 178 mean val loss:  	0.44461655616760254
# Epoch 179 mean train loss:	0.22144997119903564
# Epoch 179 mean val loss:  	0.41229891777038574
# Epoch 180 mean train loss:	0.22164203226566315
# Epoch 180 mean val loss:  	0.37536582350730896
# Epoch 181 mean train loss:	0.2191466987133026
# Epoch 181 mean val loss:  	0.42388778924942017
# Epoch 182 mean train loss:	0.22739820182323456
# Epoch 182 mean val loss:  	0.3727335035800934
# Epoch 183 mean train loss:	0.2030973881483078
# Epoch 183 mean val loss:  	0.3127805292606354
# Epoch 184 mean train loss:	0.20744331181049347
# Epoch 184 mean val loss:  	0.41349947452545166
# Epoch 185 mean train loss:	0.20078255236148834
# Epoch 185 mean val loss:  	0.407501220703125
# Epoch 186 mean train loss:	0.20029491186141968
# Epoch 186 mean val loss:  	0.4456062912940979
# Epoch 187 mean train loss:	0.22512176632881165
# Epoch 187 mean val loss:  	0.4183647036552429
# Epoch 188 mean train loss:	0.2103087306022644
# Epoch 188 mean val loss:  	0.4115898013114929
# Epoch 189 mean train loss:	0.23363164067268372
# Epoch 189 mean val loss:  	0.5259121656417847
# Epoch 190 mean train loss:	0.20438627898693085
# Epoch 190 mean val loss:  	0.4206317961215973
# Epoch 191 mean train loss:	0.2237817943096161
# Epoch 191 mean val loss:  	0.42707592248916626
# Epoch 192 mean train loss:	0.22400204837322235
# Epoch 192 mean val loss:  	0.35922664403915405
# Epoch 193 mean train loss:	0.1922382265329361
# Epoch 193 mean val loss:  	0.3493501543998718
# Epoch 194 mean train loss:	0.2050510048866272
# Epoch 194 mean val loss:  	0.34275922179222107
# Epoch 195 mean train loss:	0.20452630519866943
# Epoch 195 mean val loss:  	0.35645657777786255
# Epoch 196 mean train loss:	0.21611283719539642
# Epoch 196 mean val loss:  	0.3608655035495758
# Epoch 197 mean train loss:	0.19915789365768433
# Epoch 197 mean val loss:  	0.366818904876709
# Epoch 198 mean train loss:	0.19640657305717468
# Epoch 198 mean val loss:  	0.3784937560558319
# Epoch 199 mean train loss:	0.20181748270988464
# Epoch 199 mean val loss:  	0.34529033303260803
# Epoch 200 mean train loss:	0.21739037334918976
# Epoch 200 mean val loss:  	0.4470057189464569
# Epoch 201 mean train loss:	0.19583366811275482
# Epoch 201 mean val loss:  	0.34885120391845703
# Epoch 202 mean train loss:	0.18654298782348633
# Epoch 202 mean val loss:  	0.3730468153953552
# Epoch 203 mean train loss:	0.18576109409332275
# Epoch 203 mean val loss:  	0.3479784429073334
# Epoch 204 mean train loss:	0.2073289304971695
# Epoch 204 mean val loss:  	0.3476768434047699
# Epoch 205 mean train loss:	0.18468794226646423
# Epoch 205 mean val loss:  	0.34576132893562317
# Epoch 206 mean train loss:	0.20673814415931702
# Epoch 206 mean val loss:  	0.3415878117084503
# Epoch 207 mean train loss:	0.1982046365737915
# Epoch 207 mean val loss:  	0.3941898047924042
# Epoch 208 mean train loss:	0.19762879610061646
# Epoch 208 mean val loss:  	0.3419995903968811
# Epoch 209 mean train loss:	0.19805696606636047
# Epoch 209 mean val loss:  	0.3333480656147003
# Epoch 210 mean train loss:	0.18781410157680511
# Epoch 210 mean val loss:  	0.3522137403488159
# Epoch 211 mean train loss:	0.2028426080942154
# Epoch 211 mean val loss:  	0.3772338330745697
# Epoch 212 mean train loss:	0.2041245847940445
# Epoch 212 mean val loss:  	0.42747318744659424
# Epoch 213 mean train loss:	0.18764375150203705
# Epoch 213 mean val loss:  	0.3289746642112732
# Epoch 214 mean train loss:	0.1911894977092743
# Epoch 214 mean val loss:  	0.3330872654914856
# Epoch 215 mean train loss:	0.1897743195295334
# Epoch 215 mean val loss:  	0.3654952645301819
# Epoch 216 mean train loss:	0.17879702150821686
# Epoch 216 mean val loss:  	0.3118959963321686
# Epoch 217 mean train loss:	0.1778193861246109
# Epoch 217 mean val loss:  	0.3073354959487915
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 218 mean train loss:	0.182428777217865
# Epoch 218 mean val loss:  	0.4409223198890686
# Epoch 219 mean train loss:	0.18372087180614471
# Epoch 219 mean val loss:  	0.3547285795211792
# Epoch 220 mean train loss:	0.1915391981601715
# Epoch 220 mean val loss:  	0.33638155460357666
# Epoch 221 mean train loss:	0.1924034208059311
# Epoch 221 mean val loss:  	0.32380178570747375
# Epoch 222 mean train loss:	0.1917874962091446
# Epoch 222 mean val loss:  	0.4199291169643402
# Epoch 223 mean train loss:	0.2055186778306961
# Epoch 223 mean val loss:  	0.31264808773994446
# Epoch 224 mean train loss:	0.1997482180595398
# Epoch 224 mean val loss:  	0.3392145335674286
# Epoch 225 mean train loss:	0.1913815438747406
# Epoch 225 mean val loss:  	0.34255674481391907
# Epoch 226 mean train loss:	0.20642711222171783
# Epoch 226 mean val loss:  	0.3758361041545868
# Epoch 227 mean train loss:	0.19949910044670105
# Epoch 227 mean val loss:  	0.45744121074676514
# Epoch 228 mean train loss:	0.17892159521579742
# Epoch 228 mean val loss:  	0.3262067139148712
# Epoch 229 mean train loss:	0.17875781655311584
# Epoch 229 mean val loss:  	0.33367452025413513
# Epoch 230 mean train loss:	0.1859188675880432
# Epoch 230 mean val loss:  	0.36202675104141235
# Epoch 231 mean train loss:	0.1927766501903534
# Epoch 231 mean val loss:  	0.4259660243988037
# Epoch 232 mean train loss:	0.1863681524991989
# Epoch 232 mean val loss:  	0.3220166862010956
# Epoch 233 mean train loss:	0.18021196126937866
# Epoch 233 mean val loss:  	0.38631099462509155
# Epoch 234 mean train loss:	0.17609082162380219
# Epoch 234 mean val loss:  	0.4294199049472809
# Epoch 235 mean train loss:	0.1895303875207901
# Epoch 235 mean val loss:  	0.3546709418296814
# Epoch 236 mean train loss:	0.19858327507972717
# Epoch 236 mean val loss:  	0.3681652843952179
# Epoch 237 mean train loss:	0.195956751704216
# Epoch 237 mean val loss:  	0.35354897379875183
# Epoch 238 mean train loss:	0.181598961353302
# Epoch 238 mean val loss:  	0.3951205313205719
# Epoch 239 mean train loss:	0.191471129655838
# Epoch 239 mean val loss:  	0.41573086380958557
# Epoch 240 mean train loss:	0.1918642669916153
# Epoch 240 mean val loss:  	0.3664553761482239
# Epoch 241 mean train loss:	0.19692446291446686
# Epoch 241 mean val loss:  	0.3709104657173157
# Epoch 242 mean train loss:	0.18303579092025757
# Epoch 242 mean val loss:  	0.37808334827423096
# Epoch 243 mean train loss:	0.16857923567295074
# Epoch 243 mean val loss:  	0.3980964422225952
# Epoch 244 mean train loss:	0.16900740563869476
# Epoch 244 mean val loss:  	0.31518104672431946
# Epoch 245 mean train loss:	0.17190062999725342
# Epoch 245 mean val loss:  	0.30004745721817017
# Epoch 246 mean train loss:	0.17728367447853088
# Epoch 246 mean val loss:  	0.3719280958175659
# Epoch 247 mean train loss:	0.17617179453372955
# Epoch 247 mean val loss:  	0.3214687407016754
# Epoch 248 mean train loss:	0.1827300786972046
# Epoch 248 mean val loss:  	0.3959929347038269
# Epoch 249 mean train loss:	0.16388531029224396
# Epoch 249 mean val loss:  	0.39968812465667725
# Epoch 250 mean train loss:	0.17658723890781403
# Epoch 250 mean val loss:  	0.3657098114490509
# Epoch 251 mean train loss:	0.1740541309118271
# Epoch 251 mean val loss:  	0.3306249678134918
# Epoch 252 mean train loss:	0.16243159770965576
# Epoch 252 mean val loss:  	0.32352718710899353
# Epoch 253 mean train loss:	0.1573195457458496
# Epoch 253 mean val loss:  	0.33250269293785095
# Epoch 254 mean train loss:	0.1867576688528061
# Epoch 254 mean val loss:  	0.36522531509399414
# Epoch 255 mean train loss:	0.18116626143455505
# Epoch 255 mean val loss:  	0.3926059305667877
# Epoch 256 mean train loss:	0.1691676825284958
# Epoch 256 mean val loss:  	0.3179941475391388
# Epoch 257 mean train loss:	0.16962260007858276
# Epoch 257 mean val loss:  	0.3656489849090576
# Epoch 258 mean train loss:	0.1696656495332718
# Epoch 258 mean val loss:  	0.3677542507648468
# Epoch 259 mean train loss:	0.16568057239055634
# Epoch 259 mean val loss:  	0.3790535628795624
# Epoch 260 mean train loss:	0.1592775285243988
# Epoch 260 mean val loss:  	0.33519113063812256
# Epoch 261 mean train loss:	0.15846747159957886
# Epoch 261 mean val loss:  	0.4171268939971924
# Epoch 262 mean train loss:	0.17999683320522308
# Epoch 262 mean val loss:  	0.32582494616508484
# Epoch 263 mean train loss:	0.17566858232021332
# Epoch 263 mean val loss:  	0.34171563386917114
# Epoch 264 mean train loss:	0.17106415331363678
# Epoch 264 mean val loss:  	0.37886542081832886
# Epoch 265 mean train loss:	0.18171426653862
# Epoch 265 mean val loss:  	0.38102251291275024
# Epoch 266 mean train loss:	0.1737433522939682
# Epoch 266 mean val loss:  	0.3484533727169037
# Epoch 267 mean train loss:	0.1683678925037384
# Epoch 267 mean val loss:  	0.4064714312553406
# Epoch 268 mean train loss:	0.16317972540855408
# Epoch 268 mean val loss:  	0.33758631348609924
# Epoch 269 mean train loss:	0.1606685370206833
# Epoch 269 mean val loss:  	0.4049151837825775
# Epoch 270 mean train loss:	0.15091437101364136
# Epoch 270 mean val loss:  	0.3596411943435669
# Epoch 271 mean train loss:	0.14810408651828766
# Epoch 271 mean val loss:  	0.3681375980377197
# Epoch 272 mean train loss:	0.15214751660823822
# Epoch 272 mean val loss:  	0.3607850968837738
# Epoch 273 mean train loss:	0.15557976067066193
# Epoch 273 mean val loss:  	0.3037005662918091
# Epoch 274 mean train loss:	0.14339573681354523
# Epoch 274 mean val loss:  	0.5037955641746521
# Epoch 275 mean train loss:	0.1439756453037262
# Epoch 275 mean val loss:  	0.34157654643058777
# Epoch 276 mean train loss:	0.15488004684448242
# Epoch 276 mean val loss:  	0.3478035628795624
# Epoch 277 mean train loss:	0.1534656137228012
# Epoch 277 mean val loss:  	0.3746879994869232
# Epoch 278 mean train loss:	0.14768435060977936
# Epoch 278 mean val loss:  	0.34157800674438477
# Epoch 279 mean train loss:	0.1484883427619934
# Epoch 279 mean val loss:  	0.4387790858745575
# Epoch 280 mean train loss:	0.16296425461769104
# Epoch 280 mean val loss:  	0.31137335300445557
# Epoch 281 mean train loss:	0.15639746189117432
# Epoch 281 mean val loss:  	0.32312652468681335
# Epoch 282 mean train loss:	0.16037552058696747
# Epoch 282 mean val loss:  	0.3541881740093231
# Epoch 283 mean train loss:	0.14887933433055878
# Epoch 283 mean val loss:  	0.34949180483818054
# Epoch 284 mean train loss:	0.15074722468852997
# Epoch 284 mean val loss:  	0.4130857586860657
# Epoch 285 mean train loss:	0.16221679747104645
# Epoch 285 mean val loss:  	0.29612088203430176
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 286 mean train loss:	0.15225793421268463
# Epoch 286 mean val loss:  	0.36375755071640015
# Epoch 287 mean train loss:	0.15436649322509766
# Epoch 287 mean val loss:  	0.3255288004875183
# Epoch 288 mean train loss:	0.1514504849910736
# Epoch 288 mean val loss:  	0.3003964126110077
# Epoch 289 mean train loss:	0.1520797461271286
# Epoch 289 mean val loss:  	0.3223314881324768
# Epoch 290 mean train loss:	0.1469922959804535
# Epoch 290 mean val loss:  	0.4482608437538147
# Epoch 291 mean train loss:	0.14818379282951355
# Epoch 291 mean val loss:  	0.37418708205223083
# Epoch 292 mean train loss:	0.15570680797100067
# Epoch 292 mean val loss:  	0.37403732538223267
# Epoch 293 mean train loss:	0.16005532443523407
# Epoch 293 mean val loss:  	0.31184980273246765
# Epoch 294 mean train loss:	0.1573532372713089
# Epoch 294 mean val loss:  	0.3242930769920349
# Epoch 295 mean train loss:	0.1682591587305069
# Epoch 295 mean val loss:  	0.32896363735198975
# Epoch 296 mean train loss:	0.1674291342496872
# Epoch 296 mean val loss:  	0.3600010871887207
# Epoch 297 mean train loss:	0.1671639084815979
# Epoch 297 mean val loss:  	0.3451363444328308
# Epoch 298 mean train loss:	0.17085117101669312
# Epoch 298 mean val loss:  	0.3202374577522278
# Epoch 299 mean train loss:	0.14538833498954773
# Epoch 299 mean val loss:  	0.41475439071655273
# Epoch 300 mean train loss:	0.15545116364955902
# Epoch 300 mean val loss:  	0.35818177461624146
# Epoch 301 mean train loss:	0.15012234449386597
# Epoch 301 mean val loss:  	0.3594311773777008
# Epoch 302 mean train loss:	0.1537409871816635
# Epoch 302 mean val loss:  	0.35227715969085693
# Epoch 303 mean train loss:	0.15057975053787231
# Epoch 303 mean val loss:  	0.30688348412513733
# Epoch 304 mean train loss:	0.14287999272346497
# Epoch 304 mean val loss:  	0.3949170708656311
# Epoch 305 mean train loss:	0.1397036910057068
# Epoch 305 mean val loss:  	0.33797329664230347
# Epoch 306 mean train loss:	0.1393284648656845
# Epoch 306 mean val loss:  	0.34141233563423157
# Epoch 307 mean train loss:	0.14423219859600067
# Epoch 307 mean val loss:  	0.31089475750923157
# Epoch 308 mean train loss:	0.1485738605260849
# Epoch 308 mean val loss:  	0.32442039251327515
# Epoch 309 mean train loss:	0.1431887447834015
# Epoch 309 mean val loss:  	0.48330193758010864
# Epoch 310 mean train loss:	0.13998988270759583
# Epoch 310 mean val loss:  	0.3205130100250244
# Epoch 311 mean train loss:	0.15318424999713898
# Epoch 311 mean val loss:  	0.31114375591278076
# Epoch 312 mean train loss:	0.15081579983234406
# Epoch 312 mean val loss:  	0.2880041003227234
# Epoch 313 mean train loss:	0.1454959362745285
# Epoch 313 mean val loss:  	0.3213447630405426
# Epoch 314 mean train loss:	0.14402808248996735
# Epoch 314 mean val loss:  	0.33459022641181946
# Epoch 315 mean train loss:	0.14659933745861053
# Epoch 315 mean val loss:  	0.3491363823413849
# Epoch 316 mean train loss:	0.14042054116725922
# Epoch 316 mean val loss:  	0.36422479152679443
# Epoch 317 mean train loss:	0.14705203473567963
# Epoch 317 mean val loss:  	0.327457457780838
# Epoch 318 mean train loss:	0.15114174783229828
# Epoch 318 mean val loss:  	0.3656461834907532
# Epoch 319 mean train loss:	0.15090656280517578
# Epoch 319 mean val loss:  	0.33975714445114136
# Epoch 320 mean train loss:	0.14143073558807373
# Epoch 320 mean val loss:  	0.4517573118209839
# Epoch 321 mean train loss:	0.14915364980697632
# Epoch 321 mean val loss:  	0.3670682907104492
# Epoch 322 mean train loss:	0.15899479389190674
# Epoch 322 mean val loss:  	0.36839765310287476
# Epoch 323 mean train loss:	0.14311784505844116
# Epoch 323 mean val loss:  	0.39713534712791443
# Epoch 324 mean train loss:	0.1488027572631836
# Epoch 324 mean val loss:  	0.363735556602478
# Epoch 325 mean train loss:	0.1669044941663742
# Epoch 325 mean val loss:  	0.38252002000808716
# Epoch 326 mean train loss:	0.15203207731246948
# Epoch 326 mean val loss:  	0.36646589636802673
# Epoch 327 mean train loss:	0.15626117587089539
# Epoch 327 mean val loss:  	0.42165669798851013
# Epoch 328 mean train loss:	0.14624570310115814
# Epoch 328 mean val loss:  	0.3464413583278656
# Epoch 329 mean train loss:	0.1415022313594818
# Epoch 329 mean val loss:  	0.3322186768054962
# Epoch 330 mean train loss:	0.1410788893699646
# Epoch 330 mean val loss:  	0.46455955505371094
# Epoch 331 mean train loss:	0.13849174976348877
# Epoch 331 mean val loss:  	0.39442509412765503
# Epoch 332 mean train loss:	0.14259424805641174
# Epoch 332 mean val loss:  	0.33249154686927795
# Epoch 333 mean train loss:	0.14642752707004547
# Epoch 333 mean val loss:  	0.32047778367996216
# Epoch 334 mean train loss:	0.13753579556941986
# Epoch 334 mean val loss:  	0.31539082527160645
# Epoch 335 mean train loss:	0.14018100500106812
# Epoch 335 mean val loss:  	0.4016714096069336
# Epoch 336 mean train loss:	0.14200809597969055
# Epoch 336 mean val loss:  	0.38759347796440125
# Epoch 337 mean train loss:	0.1403454691171646
# Epoch 337 mean val loss:  	0.3813899755477905
# Epoch 338 mean train loss:	0.1515665054321289
# Epoch 338 mean val loss:  	0.3639010488986969
# Epoch 339 mean train loss:	0.14409056305885315
# Epoch 339 mean val loss:  	0.3385954201221466
# Epoch 340 mean train loss:	0.13817182183265686
# Epoch 340 mean val loss:  	0.3672371208667755
# Epoch 341 mean train loss:	0.12200582772493362
# Epoch 341 mean val loss:  	0.3247303366661072
# Epoch 342 mean train loss:	0.1349944770336151
# Epoch 342 mean val loss:  	0.37700819969177246
# Epoch 343 mean train loss:	0.12817013263702393
# Epoch 343 mean val loss:  	0.32928696274757385
# Epoch 344 mean train loss:	0.14312943816184998
# Epoch 344 mean val loss:  	0.32194268703460693
# Epoch 345 mean train loss:	0.1321931779384613
# Epoch 345 mean val loss:  	0.3969419598579407
# Epoch 346 mean train loss:	0.15100860595703125
# Epoch 346 mean val loss:  	0.331047385931015
# Epoch 347 mean train loss:	0.14871689677238464
# Epoch 347 mean val loss:  	0.3490214943885803
# Epoch 348 mean train loss:	0.14525106549263
# Epoch 348 mean val loss:  	0.8511505722999573
# Epoch 349 mean train loss:	0.1458238661289215
# Epoch 349 mean val loss:  	0.360066294670105
# Epoch 350 mean train loss:	0.15165311098098755
# Epoch 350 mean val loss:  	0.40829822421073914
# Epoch 351 mean train loss:	0.1535787731409073
# Epoch 351 mean val loss:  	0.3050627112388611
# Epoch 352 mean train loss:	0.15322409570217133
# Epoch 352 mean val loss:  	0.38303476572036743
# Epoch 353 mean train loss:	0.1491248458623886
# Epoch 353 mean val loss:  	0.32357221841812134
# Epoch 354 mean train loss:	0.1396140456199646
# Epoch 354 mean val loss:  	0.2952316105365753
# Epoch 355 mean train loss:	0.13997489213943481
# Epoch 355 mean val loss:  	0.3380320370197296
# Epoch 356 mean train loss:	0.14158941805362701
# Epoch 356 mean val loss:  	0.37190401554107666
# Epoch 357 mean train loss:	0.1284935176372528
# Epoch 357 mean val loss:  	0.3999883532524109
# Epoch 358 mean train loss:	0.13403621315956116
# Epoch 358 mean val loss:  	0.43802088499069214
# Epoch 359 mean train loss:	0.1512884646654129
# Epoch 359 mean val loss:  	0.3594333529472351
# Epoch 360 mean train loss:	0.13797731697559357
# Epoch 360 mean val loss:  	0.3386062681674957
# Epoch 361 mean train loss:	0.13539253175258636
# Epoch 361 mean val loss:  	0.31434324383735657
# Epoch 362 mean train loss:	0.13256780803203583
# Epoch 362 mean val loss:  	0.3451785743236542
# Epoch 363 mean train loss:	0.1370200216770172
# Epoch 363 mean val loss:  	0.37840431928634644
# Epoch 364 mean train loss:	0.1397266685962677
# Epoch 364 mean val loss:  	0.37569451332092285
# Epoch 365 mean train loss:	0.13491623103618622
# Epoch 365 mean val loss:  	0.479308545589447
# Epoch 366 mean train loss:	0.12960146367549896
# Epoch 366 mean val loss:  	0.2575192451477051
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl
# Epoch 367 mean train loss:	0.13225777447223663
# Epoch 367 mean val loss:  	0.31752604246139526
# Epoch 368 mean train loss:	0.13164860010147095
# Epoch 368 mean val loss:  	0.3249988257884979
# Epoch 369 mean train loss:	0.13036015629768372
# Epoch 369 mean val loss:  	0.28624558448791504
# Epoch 370 mean train loss:	0.12920846045017242
# Epoch 370 mean val loss:  	0.35475265979766846
# Epoch 371 mean train loss:	0.12615643441677094
# Epoch 371 mean val loss:  	0.38083183765411377
# Epoch 372 mean train loss:	0.12969882786273956
# Epoch 372 mean val loss:  	0.3437483310699463
# Epoch 373 mean train loss:	0.13140343129634857
# Epoch 373 mean val loss:  	0.3642355799674988
# Epoch 374 mean train loss:	0.1267767697572708
# Epoch 374 mean val loss:  	0.46571123600006104
# Epoch 375 mean train loss:	0.11792522668838501
# Epoch 375 mean val loss:  	0.30975285172462463
# Epoch 376 mean train loss:	0.12807367742061615
# Epoch 376 mean val loss:  	0.3308309316635132
# Epoch 377 mean train loss:	0.12572802603244781
# Epoch 377 mean val loss:  	0.3670117259025574
# Epoch 378 mean train loss:	0.12921494245529175
# Epoch 378 mean val loss:  	0.45554837584495544
# Epoch 379 mean train loss:	0.12795297801494598
# Epoch 379 mean val loss:  	0.3615119755268097
# Epoch 380 mean train loss:	0.1410895138978958
# Epoch 380 mean val loss:  	0.3809541165828705
# Epoch 381 mean train loss:	0.13843761384487152
# Epoch 381 mean val loss:  	0.3303399085998535
# Epoch 382 mean train loss:	0.14686639606952667
# Epoch 382 mean val loss:  	0.33094823360443115
# Epoch 383 mean train loss:	0.13716907799243927
# Epoch 383 mean val loss:  	0.28996938467025757
# Epoch 384 mean train loss:	0.12981197237968445
# Epoch 384 mean val loss:  	0.38198572397232056
# Epoch 385 mean train loss:	0.12638509273529053
# Epoch 385 mean val loss:  	0.34042099118232727
# Epoch 386 mean train loss:	0.12944835424423218
# Epoch 386 mean val loss:  	0.3099782466888428
# Epoch 387 mean train loss:	0.12415803968906403
# Epoch 387 mean val loss:  	0.3202221989631653
# Epoch 388 mean train loss:	0.1343861073255539
# Epoch 388 mean val loss:  	0.3564707636833191
# Epoch 389 mean train loss:	0.13517813384532928
# Epoch 389 mean val loss:  	0.3479941189289093
# Epoch 390 mean train loss:	0.12153934687376022
# Epoch 390 mean val loss:  	0.38957586884498596
# Epoch 391 mean train loss:	0.12074598670005798
# Epoch 391 mean val loss:  	0.3621178865432739
# Epoch 392 mean train loss:	0.12212835252285004
# Epoch 392 mean val loss:  	0.3272493779659271
# Epoch 393 mean train loss:	0.12392304837703705
# Epoch 393 mean val loss:  	0.3170452117919922
# Epoch 394 mean train loss:	0.1299886852502823
# Epoch 394 mean val loss:  	0.34705227613449097
# Epoch 395 mean train loss:	0.12392181903123856
# Epoch 395 mean val loss:  	0.36533576250076294
# Epoch 396 mean train loss:	0.12763133645057678
# Epoch 396 mean val loss:  	0.29971253871917725
# Epoch 397 mean train loss:	0.120893694460392
# Epoch 397 mean val loss:  	0.3040241003036499
# Epoch 398 mean train loss:	0.1209949180483818
# Epoch 398 mean val loss:  	0.35078367590904236
# Epoch 399 mean train loss:	0.1185629591345787
# Epoch 399 mean val loss:  	0.32755425572395325
# Epoch 400 mean train loss:	0.11473970860242844
# Epoch 400 mean val loss:  	0.35962948203086853
# Epoch 401 mean train loss:	0.12282230705022812
# Epoch 401 mean val loss:  	0.3880927264690399
# Epoch 402 mean train loss:	0.1187785193324089
# Epoch 402 mean val loss:  	0.29681628942489624
# Epoch 403 mean train loss:	0.11707288026809692
# Epoch 403 mean val loss:  	0.3272879123687744
# Epoch 404 mean train loss:	0.12169699370861053
# Epoch 404 mean val loss:  	0.2927972674369812
# Epoch 405 mean train loss:	0.11657287925481796
# Epoch 405 mean val loss:  	0.3415870666503906
# Epoch 406 mean train loss:	0.12202931940555573
# Epoch 406 mean val loss:  	0.3185969293117523
# Epoch 407 mean train loss:	0.11637161672115326
# Epoch 407 mean val loss:  	0.33763575553894043
# Epoch 408 mean train loss:	0.11612457782030106
# Epoch 408 mean val loss:  	0.37409451603889465
# Epoch 409 mean train loss:	0.12117418646812439
# Epoch 409 mean val loss:  	0.30391350388526917
# Epoch 410 mean train loss:	0.12420724332332611
# Epoch 410 mean val loss:  	0.3453197479248047
# Epoch 411 mean train loss:	0.1340361088514328
# Epoch 411 mean val loss:  	0.37107789516448975
# Epoch 412 mean train loss:	0.1317175179719925
# Epoch 412 mean val loss:  	0.3562195599079132
# Epoch 413 mean train loss:	0.1249028742313385
# Epoch 413 mean val loss:  	0.34039610624313354
# Epoch 414 mean train loss:	0.12339745461940765
# Epoch 414 mean val loss:  	0.33057141304016113
# Epoch 415 mean train loss:	0.12284247577190399
# Epoch 415 mean val loss:  	0.30199241638183594
# Epoch 416 mean train loss:	0.1238119900226593
# Epoch 416 mean val loss:  	0.3684821128845215
# Epoch 417 mean train loss:	0.12484506517648697
# Epoch 417 mean val loss:  	0.34549957513809204
# Epoch 418 mean train loss:	0.11752103269100189
# Epoch 418 mean val loss:  	0.42011696100234985
# Epoch 419 mean train loss:	0.12834013998508453
# Epoch 419 mean val loss:  	0.3389672040939331
# Epoch 420 mean train loss:	0.1365034431219101
# Epoch 420 mean val loss:  	0.38609156012535095
# Epoch 421 mean train loss:	0.12903356552124023
# Epoch 421 mean val loss:  	0.38494813442230225
# Epoch 422 mean train loss:	0.12237609922885895
# Epoch 422 mean val loss:  	0.37682369351387024
# Epoch 423 mean train loss:	0.12498815357685089
# Epoch 423 mean val loss:  	0.35882872343063354
# Epoch 424 mean train loss:	0.12836162745952606
# Epoch 424 mean val loss:  	0.33815035223960876
# Epoch 425 mean train loss:	0.1238131895661354
# Epoch 425 mean val loss:  	0.3450886607170105
# Epoch 426 mean train loss:	0.1289089024066925
# Epoch 426 mean val loss:  	0.3634431064128876
# Epoch 427 mean train loss:	0.12720897793769836
# Epoch 427 mean val loss:  	0.3822476863861084
# Epoch 428 mean train loss:	0.1315109133720398
# Epoch 428 mean val loss:  	0.35963866114616394
# Epoch 429 mean train loss:	0.11919452995061874
# Epoch 429 mean val loss:  	0.3428875207901001
# Epoch 430 mean train loss:	0.12161927670240402
# Epoch 430 mean val loss:  	0.37442752718925476
# Epoch 431 mean train loss:	0.12177950888872147
# Epoch 431 mean val loss:  	0.3481101393699646
# Epoch 432 mean train loss:	0.12429089099168777
# Epoch 432 mean val loss:  	0.37737971544265747
# Epoch 433 mean train loss:	0.12521395087242126
# Epoch 433 mean val loss:  	0.37770217657089233
# Epoch 434 mean train loss:	0.1234312579035759
# Epoch 434 mean val loss:  	0.37132275104522705
# Epoch 435 mean train loss:	0.11271451413631439
# Epoch 435 mean val loss:  	0.32841745018959045
# Epoch 436 mean train loss:	0.11081280559301376
# Epoch 436 mean val loss:  	0.3884836435317993
# Epoch 437 mean train loss:	0.11256718635559082
# Epoch 437 mean val loss:  	0.3345808982849121
# Epoch 438 mean train loss:	0.11594512313604355
# Epoch 438 mean val loss:  	0.4850601851940155
# Epoch 439 mean train loss:	0.1161021739244461
# Epoch 439 mean val loss:  	0.39118248224258423
# Epoch 440 mean train loss:	0.11564096063375473
# Epoch 440 mean val loss:  	0.3119264245033264
# Epoch 441 mean train loss:	0.1159825325012207
# Epoch 441 mean val loss:  	0.3997730016708374
# Epoch 442 mean train loss:	0.12229437381029129
# Epoch 442 mean val loss:  	0.3276023268699646
# Epoch 443 mean train loss:	0.11928004026412964
# Epoch 443 mean val loss:  	0.3700624704360962
# Epoch 444 mean train loss:	0.1278512328863144
# Epoch 444 mean val loss:  	0.3754599690437317
# Epoch 445 mean train loss:	0.12317536771297455
# Epoch 445 mean val loss:  	0.3170187473297119
# Epoch 446 mean train loss:	0.11810316890478134
# Epoch 446 mean val loss:  	0.3442045748233795
# Epoch 447 mean train loss:	0.11749468743801117
# Epoch 447 mean val loss:  	0.3886756896972656
# Epoch 448 mean train loss:	0.12997686862945557
# Epoch 448 mean val loss:  	0.3779885768890381
# Epoch 449 mean train loss:	0.12221290916204453
# Epoch 449 mean val loss:  	0.3209046721458435
# Epoch 450 mean train loss:	0.12015833705663681
# Epoch 450 mean val loss:  	0.33659273386001587
# Epoch 451 mean train loss:	0.11869053542613983
# Epoch 451 mean val loss:  	0.359622061252594
# Epoch 452 mean train loss:	0.11782316118478775
# Epoch 452 mean val loss:  	0.32138705253601074
# Epoch 453 mean train loss:	0.11939050257205963
# Epoch 453 mean val loss:  	0.34704259037971497
# Epoch 454 mean train loss:	0.12535563111305237
# Epoch 454 mean val loss:  	0.3709113895893097
# Epoch 455 mean train loss:	0.12714353203773499
# Epoch 455 mean val loss:  	0.44053298234939575
# Epoch 456 mean train loss:	0.11622419208288193
# Epoch 456 mean val loss:  	0.3205487132072449
# Epoch 457 mean train loss:	0.11590495705604553
# Epoch 457 mean val loss:  	0.3849555253982544
# Epoch 458 mean train loss:	0.11146394908428192
# Epoch 458 mean val loss:  	0.3166734278202057
# Epoch 459 mean train loss:	0.11650055646896362
# Epoch 459 mean val loss:  	0.3123733103275299
# Epoch 460 mean train loss:	0.11793547123670578
# Epoch 460 mean val loss:  	0.3836047947406769
# Epoch 461 mean train loss:	0.1127103939652443
# Epoch 461 mean val loss:  	0.3599942922592163
# Epoch 462 mean train loss:	0.11474134027957916
# Epoch 462 mean val loss:  	0.3023907542228699
# Epoch 463 mean train loss:	0.1165076419711113
# Epoch 463 mean val loss:  	0.31204453110694885
# Epoch 464 mean train loss:	0.11313781887292862
# Epoch 464 mean val loss:  	0.2984229028224945
# Epoch 465 mean train loss:	0.11399365961551666
# Epoch 465 mean val loss:  	0.3236868381500244
# Epoch 466 mean train loss:	0.1064290776848793
# Epoch 466 mean val loss:  	0.33331143856048584
# Epoch 467 mean train loss:	0.10601022094488144
# Epoch 467 mean val loss:  	0.28813549876213074
# Epoch 468 mean train loss:	0.10301987826824188
# Epoch 468 mean val loss:  	0.36303767561912537
# Epoch 469 mean train loss:	0.09821347147226334
# Epoch 469 mean val loss:  	0.3577004075050354
# Epoch 470 mean train loss:	0.10853465646505356
# Epoch 470 mean val loss:  	0.3597792983055115
# Epoch 471 mean train loss:	0.1035897508263588
# Epoch 471 mean val loss:  	0.33337637782096863
# Epoch 472 mean train loss:	0.11030825227499008
# Epoch 472 mean val loss:  	0.29963505268096924
# Epoch 473 mean train loss:	0.10480097681283951
# Epoch 473 mean val loss:  	0.34612929821014404
# Epoch 474 mean train loss:	0.1068006083369255
# Epoch 474 mean val loss:  	0.29369398951530457
# Epoch 475 mean train loss:	0.10175205022096634
# Epoch 475 mean val loss:  	0.3308264911174774
# Epoch 476 mean train loss:	0.10864654928445816
# Epoch 476 mean val loss:  	0.3853493928909302
# Epoch 477 mean train loss:	0.1083902046084404
# Epoch 477 mean val loss:  	0.32307350635528564
# Epoch 478 mean train loss:	0.10561246424913406
# Epoch 478 mean val loss:  	0.4241441488265991
# Epoch 479 mean train loss:	0.10745815932750702
# Epoch 479 mean val loss:  	0.3218877613544464
# Epoch 480 mean train loss:	0.10314758121967316
# Epoch 480 mean val loss:  	0.3377094268798828
# Epoch 481 mean train loss:	0.11369059979915619
# Epoch 481 mean val loss:  	0.38296377658843994
# Epoch 482 mean train loss:	0.11544042080640793
# Epoch 482 mean val loss:  	0.46957093477249146
# Epoch 483 mean train loss:	0.11490935832262039
# Epoch 483 mean val loss:  	0.32914507389068604
# Epoch 484 mean train loss:	0.11528144031763077
# Epoch 484 mean val loss:  	0.34529468417167664
# Epoch 485 mean train loss:	0.11840412020683289
# Epoch 485 mean val loss:  	0.4986385107040405
# Epoch 486 mean train loss:	0.12108268588781357
# Epoch 486 mean val loss:  	0.3928823173046112
# Epoch 487 mean train loss:	0.12024347484111786
# Epoch 487 mean val loss:  	0.34150731563568115
# Epoch 488 mean train loss:	0.12110575288534164
# Epoch 488 mean val loss:  	0.335365355014801
# Epoch 489 mean train loss:	0.11606733500957489
# Epoch 489 mean val loss:  	0.378150999546051
# Epoch 490 mean train loss:	0.11605144292116165
# Epoch 490 mean val loss:  	0.32138296961784363
# Epoch 491 mean train loss:	0.11805657297372818
# Epoch 491 mean val loss:  	0.3918551802635193
# Epoch 492 mean train loss:	0.11341796815395355
# Epoch 492 mean val loss:  	0.3260851800441742
# Epoch 493 mean train loss:	0.10692904889583588
# Epoch 493 mean val loss:  	0.3143431544303894
# Epoch 494 mean train loss:	0.10610511898994446
# Epoch 494 mean val loss:  	0.49024340510368347
# Epoch 495 mean train loss:	0.10106007754802704
# Epoch 495 mean val loss:  	0.329204797744751
# Epoch 496 mean train loss:	0.10460907220840454
# Epoch 496 mean val loss:  	0.3590380549430847
# Epoch 497 mean train loss:	0.11160605400800705
# Epoch 497 mean val loss:  	0.4424838721752167
# Epoch 498 mean train loss:	0.10254048556089401
# Epoch 498 mean val loss:  	0.35715556144714355
# Epoch 499 mean train loss:	0.10360395163297653
# Epoch 499 mean val loss:  	0.5473531484603882
# Epoch 500 mean train loss:	0.10469426214694977
# Epoch 500 mean val loss:  	0.3576757311820984
# Epoch 501 mean train loss:	0.1135869026184082
# Epoch 501 mean val loss:  	0.31196674704551697
# Epoch 502 mean train loss:	0.11037581413984299
# Epoch 502 mean val loss:  	0.29167842864990234
# Epoch 503 mean train loss:	0.10860692709684372
# Epoch 503 mean val loss:  	0.37635838985443115
# Epoch 504 mean train loss:	0.10212104022502899
# Epoch 504 mean val loss:  	0.33367428183555603
# Epoch 505 mean train loss:	0.1079748272895813
# Epoch 505 mean val loss:  	0.3188139498233795
# Epoch 506 mean train loss:	0.10928554087877274
# Epoch 506 mean val loss:  	0.3773600161075592
# Epoch 507 mean train loss:	0.1123858392238617
# Epoch 507 mean val loss:  	0.4128040671348572
# Epoch 508 mean train loss:	0.12575843930244446
# Epoch 508 mean val loss:  	0.34382766485214233
# Epoch 509 mean train loss:	0.13683010637760162
# Epoch 509 mean val loss:  	0.41122281551361084
# Epoch 510 mean train loss:	0.13062947988510132
# Epoch 510 mean val loss:  	0.31363630294799805
# Epoch 511 mean train loss:	0.12246521562337875
# Epoch 511 mean val loss:  	0.3578883409500122
# Epoch 512 mean train loss:	0.12486927956342697
# Epoch 512 mean val loss:  	0.30519628524780273
# Epoch 513 mean train loss:	0.11619067192077637
# Epoch 513 mean val loss:  	0.35003089904785156
# Epoch 514 mean train loss:	0.1221146211028099
# Epoch 514 mean val loss:  	0.3448978066444397
# Epoch 515 mean train loss:	0.11343937367200851
# Epoch 515 mean val loss:  	0.36842697858810425
# Epoch 516 mean train loss:	0.10561710596084595
# Epoch 516 mean val loss:  	0.31318652629852295
# Epoch 517 mean train loss:	0.11291760206222534
# Epoch 517 mean val loss:  	0.3275952637195587
# Epoch 518 mean train loss:	0.1080469861626625
# Epoch 518 mean val loss:  	0.33579111099243164
# Epoch 519 mean train loss:	0.11804896593093872
# Epoch 519 mean val loss:  	0.38540446758270264
# Epoch 520 mean train loss:	0.11417637020349503
# Epoch 520 mean val loss:  	0.4462133049964905
# Epoch 521 mean train loss:	0.12392477691173553
# Epoch 521 mean val loss:  	0.33913692831993103
# Epoch 522 mean train loss:	0.10938268899917603
# Epoch 522 mean val loss:  	0.36016231775283813
# Epoch 523 mean train loss:	0.10916925221681595
# Epoch 523 mean val loss:  	0.3254812955856323
# Epoch 524 mean train loss:	0.10891371965408325
# Epoch 524 mean val loss:  	0.44183486700057983
# Epoch 525 mean train loss:	0.10197407752275467
# Epoch 525 mean val loss:  	0.3638586401939392
# Epoch 526 mean train loss:	0.10214228183031082
# Epoch 526 mean val loss:  	0.30868661403656006
# Epoch 527 mean train loss:	0.109827920794487
# Epoch 527 mean val loss:  	0.33275651931762695
# Epoch 528 mean train loss:	0.10746269673109055
# Epoch 528 mean val loss:  	0.37664794921875
# Epoch 529 mean train loss:	0.10507508367300034
# Epoch 529 mean val loss:  	0.32241883873939514
# Epoch 530 mean train loss:	0.1099635437130928
# Epoch 530 mean val loss:  	0.3303276598453522
# Epoch 531 mean train loss:	0.10391250252723694
# Epoch 531 mean val loss:  	0.29733383655548096
# Epoch 532 mean train loss:	0.0987195074558258
# Epoch 532 mean val loss:  	0.3671926259994507
# Epoch 533 mean train loss:	0.1017439216375351
# Epoch 533 mean val loss:  	0.35353291034698486
# Epoch 534 mean train loss:	0.09301026910543442
# Epoch 534 mean val loss:  	0.3109908699989319
# Epoch 535 mean train loss:	0.09651444852352142
# Epoch 535 mean val loss:  	0.3155761957168579
# Epoch 536 mean train loss:	0.09735410660505295
# Epoch 536 mean val loss:  	0.31059151887893677
# Epoch 537 mean train loss:	0.09883593022823334
# Epoch 537 mean val loss:  	0.35987067222595215
# Epoch 538 mean train loss:	0.10054876655340195
# Epoch 538 mean val loss:  	0.3368690609931946
# Epoch 539 mean train loss:	0.10361714661121368
# Epoch 539 mean val loss:  	0.4265535771846771
# Epoch 540 mean train loss:	0.10837903618812561
# Epoch 540 mean val loss:  	0.3939044177532196
# Epoch 541 mean train loss:	0.10559500753879547
# Epoch 541 mean val loss:  	0.301841139793396
# Epoch 542 mean train loss:	0.10235024243593216
# Epoch 542 mean val loss:  	0.36474788188934326
# Epoch 543 mean train loss:	0.10317005217075348
# Epoch 543 mean val loss:  	0.381937175989151
# Epoch 544 mean train loss:	0.10608578473329544
# Epoch 544 mean val loss:  	0.30879446864128113
# Epoch 545 mean train loss:	0.1085352748632431
# Epoch 545 mean val loss:  	0.32005828619003296
# Epoch 546 mean train loss:	0.10523485392332077
# Epoch 546 mean val loss:  	0.4152155816555023
# Epoch 547 mean train loss:	0.10102289915084839
# Epoch 547 mean val loss:  	0.34240007400512695
# Epoch 548 mean train loss:	0.09787430614233017
# Epoch 548 mean val loss:  	0.3705829679965973
# Epoch 549 mean train loss:	0.09052444994449615
# Epoch 549 mean val loss:  	0.33461785316467285
# Epoch 550 mean train loss:	0.09631923586130142
# Epoch 550 mean val loss:  	0.3436707556247711
# Epoch 551 mean train loss:	0.09058670699596405
# Epoch 551 mean val loss:  	0.296963632106781
# Epoch 552 mean train loss:	0.09238976985216141
# Epoch 552 mean val loss:  	0.3395863175392151
# Epoch 553 mean train loss:	0.09422066807746887
# Epoch 553 mean val loss:  	0.31277960538864136
# Epoch 554 mean train loss:	0.10327927768230438
# Epoch 554 mean val loss:  	0.38923293352127075
# Epoch 555 mean train loss:	0.09604835510253906
# Epoch 555 mean val loss:  	0.36003804206848145
# Epoch 556 mean train loss:	0.09663594514131546
# Epoch 556 mean val loss:  	0.3505328893661499
# Epoch 557 mean train loss:	0.09951496124267578
# Epoch 557 mean val loss:  	0.36800915002822876
# Epoch 558 mean train loss:	0.1034759059548378
# Epoch 558 mean val loss:  	0.35735371708869934
# Epoch 559 mean train loss:	0.10526683926582336
# Epoch 559 mean val loss:  	0.35717886686325073
# Epoch 560 mean train loss:	0.10795526206493378
# Epoch 560 mean val loss:  	0.3678967356681824
# Epoch 561 mean train loss:	0.10942957550287247
# Epoch 561 mean val loss:  	0.32125166058540344
# Epoch 562 mean train loss:	0.1034296378493309
# Epoch 562 mean val loss:  	0.3006000518798828
# Epoch 563 mean train loss:	0.09928209334611893
# Epoch 563 mean val loss:  	0.34429773688316345
# Epoch 564 mean train loss:	0.09804488718509674
# Epoch 564 mean val loss:  	0.3289737105369568
# Epoch 565 mean train loss:	0.10374751687049866
# Epoch 565 mean val loss:  	0.37388476729393005
# Epoch 566 mean train loss:	0.11272571980953217
# Epoch 566 mean val loss:  	0.3051759600639343
# Epoch 567 mean train loss:	0.11553965508937836
# Epoch 567 mean val loss:  	0.3470277786254883
# Patience exhausted in epoch 567. Best val-loss was 0.2575192451477051
# Using best model from epoch 366 which had loss 0.2575192451477051
# Saved model as /home/mgauch/runoff-nn/src/../pickle/models/ConvLSTM_withLandcover_allStations_20190917-195600.pkl

# %%
logger.warning('predicting')
model.eval()

predictions = []
conv_hidden_states = None
for i, test_batch in enumerate(test_dataloader):
    if not stateful_lstm:
        conv_hidden_states = None
        
    landcover_batch = landcover.repeat(test_batch['y'].shape[0],1,1,1).to(device)
    pred, conv_hidden_states = model(test_batch['x_conv'].to(device), landcover_batch, hidden_state=conv_hidden_states)
    predictions.append(pred.detach())

predictions = torch.cat(predictions).cpu()

if stateful_lstm:
    # reorder time series
    pred_indices = np.array(list(test_sampler.__iter__())).reshape(-1)
    predictions = predictions[pred_indices.argsort()]
# Out:
# 2019-09-17 22:05:42,377 - 20190917-195600 - predicting

# %%
actuals = test_dataset.data_runoff.copy()
if len(actuals['date'].unique()) != len(predictions):
    print('Warning: length of prediction {} and actuals {} does not match.'.format(len(predictions), len(actuals['date'].unique())))

nse_list = []
mse_list = []
predictions_df = pd.DataFrame(columns=actuals.columns)
for station in actuals['station'].unique():
    row, col = test_dataset.station_to_index[station]
    
    act = actuals[actuals['station'] == station].set_index('date')['runoff']
    if predictions.shape[0] < act.shape[0]:
        print('Warning: length of prediction {} and actuals {} does not match for station {}. Ignoring excess actuals.'.format(len(predictions), len(act), station))
        act = act.iloc[:predictions.shape[0]]
    if predictions.shape[0] > act.shape[0]:
        print('Warning: length of prediction {} and actuals {} does not match for station {}. Ignoring excess predictions. (Likely this station had nan ground truth values)'.format(len(predictions), len(act), station))
    pred = pd.DataFrame({'runoff': predictions[:,row,col]}, index=test_dataset.dates)
    pred = pred.loc[act.index]
    pred['station'] = station
    predictions_df = predictions_df.append(pred.reset_index(), sort=True)
    
    nse, mse = evaluate.evaluate_daily(station, pred['runoff'], act, writer=writer)
    nse_list.append(nse)
    mse_list.append(mse)
    
    print(station, '\tNSE:', nse, '\tMSE:', mse, '(clipped to 0)')

print('Median NSE (clipped to 0)', np.median(nse_list), '/ Min', np.min(nse_list), '/ Max', np.max(nse_list))
print('Median MSE (clipped to 0)', np.median(mse_list), '/ Min', np.min(mse_list), '/ Max', np.max(mse_list))
writer.add_scalar('nse_median', np.median(nse_list))
# Out:
# /home/mgauch/miniconda3/envs/gwf/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# 04213500 	NSE: 0.6073308320090619 	MSE: 349.2416600205949 (clipped to 0)
# 04209000 	NSE: 0.7250408109193266 	MSE: 127.80030598313002 (clipped to 0)
# 04164000 	NSE: 0.6175834044458346 	MSE: 61.3972139934129 (clipped to 0)
# 04159900 	NSE: 0.6796054055930566 	MSE: 10.838652893415135 (clipped to 0)
# 04200500 	NSE: 0.6842920291396086 	MSE: 322.57207076449527 (clipped to 0)
# 04160600 	NSE: 0.7254136067958085 	MSE: 7.638148920954077 (clipped to 0)
# 04208504 	NSE: 0.7416143735732573 	MSE: 373.473895069709 (clipped to 0)
# 04199500 	NSE: 0.6872273845429939 	MSE: 149.32258687033894 (clipped to 0)
# 02GG002 	NSE: 0.6696420109544556 	MSE: 64.02647268364039 (clipped to 0)
# 02GA038 	NSE: 0.5059420121066316 	MSE: 56.44547163759325 (clipped to 0)
# 04196800 	NSE: 0.7017040750371196 	MSE: 90.32437920061685 (clipped to 0)
# 04212100 	NSE: 0.7741199438167246 	MSE: 461.31631766518103 (clipped to 0)
# 04174500 	NSE: 0.6885964422193083 	MSE: 48.94569453903733 (clipped to 0)
# 02GG003 	NSE: 0.6967999149389107 	MSE: 140.03902617375658 (clipped to 0)
# 02GG006 	NSE: 0.6561807933644059 	MSE: 19.173075366474194 (clipped to 0)
# 02GA018 	NSE: 0.5904703769437736 	MSE: 74.21303287387043 (clipped to 0)
# 04161820 	NSE: 0.6688309928679952 	MSE: 11.624428981175003 (clipped to 0)
# 04166500 	NSE: 0.23748662418738642 	MSE: 37.16947455790115 (clipped to 0)
# 04177000 	NSE: 0.6731973055424911 	MSE: 15.370749657005396 (clipped to 0)
# 04159492 	NSE: 0.6336472633599006 	MSE: 124.80522629730501 (clipped to 0)
# Warning: length of prediction 1818 and actuals 1774 does not match for station 02GC018. Ignoring excess predictions. (Likely this station had nan ground truth values)
# 02GC018 	NSE: 0.6603006538081962 	MSE: 23.847339625485056 (clipped to 0)
# 04199000 	NSE: 0.6163962584819953 	MSE: 383.22081264188273 (clipped to 0)
# 02GA047 	NSE: 0.5779436755960087 	MSE: 27.785499894365305 (clipped to 0)
# 04193500 	NSE: 0.7432855842427522 	MSE: 20740.34905571529 (clipped to 0)
# 02GD004 	NSE: 0.6285512694699535 	MSE: 16.27297473218931 (clipped to 0)
# 02GG009 	NSE: 0.6648398286528865 	MSE: 50.78810123957174 (clipped to 0)
# 04207200 	NSE: 0.7064876744219586 	MSE: 9.469085162518837 (clipped to 0)
# Warning: length of prediction 1818 and actuals 1787 does not match for station 02GG013. Ignoring excess predictions. (Likely this station had nan ground truth values)
# 02GG013 	NSE: 0.693954573294181 	MSE: 12.353826405801865 (clipped to 0)
# 04176500 	NSE: 0.6838705991503953 	MSE: 349.39840038056184 (clipped to 0)
# 04197100 	NSE: 0.7045067761584092 	MSE: 35.731431437049864 (clipped to 0)
# 02GC007 	NSE: 0.6241392352759529 	MSE: 10.496814200238676 (clipped to 0)
# 02GB001 	NSE: 0.5268877186007894 	MSE: 2548.947583851342 (clipped to 0)
# 02GA010 	NSE: 0.5677493113651422 	MSE: 144.63669698886883 (clipped to 0)
# 04213000 	NSE: 0.679324111271839 	MSE: 68.8112087750056 (clipped to 0)
# 04215000 	NSE: 0.5575007879854839 	MSE: 38.1849455852639 (clipped to 0)
# 02GC002 	NSE: 0.6646251005541638 	MSE: 38.51148390911882 (clipped to 0)
# 04165500 	NSE: -0.05649271391530308 	MSE: 489.3127744511855 (clipped to 0)
# 04198000 	NSE: 0.6961988381856989 	MSE: 2150.51833587246 (clipped to 0)
# 02GC026 	NSE: 0.6384074612076149 	MSE: 47.55878896136103 (clipped to 0)
# 02GB007 	NSE: 0.6529762373506807 	MSE: 11.1719046275738 (clipped to 0)
# 04166100 	NSE: 0.6495569248475659 	MSE: 3.2247622930097117 (clipped to 0)
# 02GC010 	NSE: 0.6165940798685954 	MSE: 17.45762605702861 (clipped to 0)
# 04215500 	NSE: 0.5628955598017235 	MSE: 71.11795534600563 (clipped to 0)
# 04195820 	NSE: 0.7070845296341977 	MSE: 444.9440309388995 (clipped to 0)
# 02GE007 	NSE: 0.5697904482939304 	MSE: 12.917399250162129 (clipped to 0)
# Warning: length of prediction 1818 and actuals 823 does not match for station 04214500. Ignoring excess predictions. (Likely this station had nan ground truth values)
# 04214500 	NSE: 0.3350131684559321 	MSE: 81.09145320502232 (clipped to 0)
# Median NSE (clipped to 0) 0.66246287718118 / Min -0.05649271391530308 / Max 0.7741199438167246
# Median MSE (clipped to 0) 58.921342815503074 / Min 3.2247622930097117 / Max 20740.34905571529

# %%
writer.close()

# %%
save_df = pd.merge(predictions_df.rename({'runoff': 'prediction'}, axis=1), actuals.rename({'runoff': 'actual'}, axis=1), 
                   on=['date', 'station'])[['date', 'station', 'prediction', 'actual']]
load_data.pickle_results('ConvLSTM_withLandcover', save_df, time_stamp)
# Out:
# 'ConvLSTM_withLandcover_20190917-195600.pkl'

# %%
datetime.now().strftime('%Y%m%d-%H%M%S')
# Out:
# '20190917-220603'
